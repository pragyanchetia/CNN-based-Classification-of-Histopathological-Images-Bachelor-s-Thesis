# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from sklearn import metrics
from google.colab import drive

# %%
IMAGE_H= 224
IMAGE_W=224
BATCH_SIZE = 32
channels = 3
epochs= 50

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_directory = '/content/drive/MyDrive/smote_balanced/enhanced_dataset'
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_directory,
    shuffle=True,
    image_size=(IMAGE_H, IMAGE_W),
    batch_size=BATCH_SIZE
)
# Out:
# Found 990 files belonging to 2 classes.

# %%
import tensorflow as tf
import os

# Constants
IMAGE_H = 224
IMAGE_W = 224
BATCH_SIZE = 32
SEED = 123

# Get the number of total images in the dataset
image_count = sum([len(files) for r, d, files in os.walk(dataset_directory) if files])
print(f"Total images found: {image_count}")

# Compute how many images go into each split
train_image_count = int(0.8 * image_count)
val_image_count = int(0.1 * image_count)
test_image_count = image_count - train_image_count - val_image_count

print(f"Training images: {train_image_count}")
print(f"Validation images: {val_image_count}")
print(f"Test images: {test_image_count}")

# Load the full dataset
full_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_directory,
    shuffle=True,
    image_size=(IMAGE_H, IMAGE_W),
    batch_size=BATCH_SIZE,
    seed=SEED
)

# Split the dataset by batches
total_batches = len(full_dataset)
train_batches = int(0.8 * total_batches)
val_batches = int(0.1 * total_batches)
test_batches = total_batches - train_batches - val_batches

train_dataset = full_dataset.take(train_batches)
val_dataset = full_dataset.skip(train_batches).take(val_batches)
test_dataset = full_dataset.skip(train_batches + val_batches)

# Prefetch for performance
AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

print(f"\nBatches:")
print(f"Training data: {train_batches} batches")
print(f"Validation data: {val_batches} batches")
print(f"Test data: {test_batches} batches")
# Out:
# Total images found: 990
# Training images: 792
# Validation images: 99
# Test images: 99
# Found 990 files belonging to 2 classes.
#
# Batches:
# Training data: 24 batches
# Validation data: 3 batches
# Test data: 4 batches

# %%
BATCH_SIZE = 32
IMAGE_H, IMAGE_W = 224, 224
CHANNELS = 3
N_CLASSES = 2

model = models.Sequential([
    layers.Conv2D(32, kernel_size=(5, 5), activation='relu', input_shape=(IMAGE_H, IMAGE_W, CHANNELS)),
    layers.Conv2D(32, kernel_size=(5, 5), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.40),
    layers.Conv2D(64, kernel_size=(5, 5), activation='relu'),
    layers.Conv2D(64, kernel_size=(5, 5), activation='relu'),
    layers.Conv2D(64, kernel_size=(5, 5), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.40),
    layers.Conv2D(128, kernel_size=(5, 5), activation='relu'),
    layers.Conv2D(128, kernel_size=(5, 5), activation='relu'),
    layers.Conv2D(128, kernel_size=(5, 5), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 220, 220, 32)   │         2,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 216, 216, 32)   │        25,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 108, 108, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 108, 108, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 104, 104, 64)   │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 100, 100, 64)   │       102,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 96, 96, 64)     │       102,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 44, 44, 128)    │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 40, 40, 128)    │       409,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 36, 36, 128)    │       409,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 18, 18, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 41472)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │    10,617,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,968,993 (45.66 MB)
#  Trainable params: 11,968,993 (45.66 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
loss_fn = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

# %%
model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

# %%
history=model.fit(
    train_dataset,
    epochs=epochs,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data=val_dataset,
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/nn.py:780: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 164s 5s/step - accuracy: 0.5283 - loss: 1.5701 - val_accuracy: 0.5417 - val_loss: 0.6882
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 394ms/step - accuracy: 0.5196 - loss: 0.6961 - val_accuracy: 0.5104 - val_loss: 0.6912
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 309ms/step - accuracy: 0.4931 - loss: 0.6952 - val_accuracy: 0.4583 - val_loss: 0.6935
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 327ms/step - accuracy: 0.5203 - loss: 0.6933 - val_accuracy: 0.5625 - val_loss: 0.6784
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - accuracy: 0.5183 - loss: 0.6976 - val_accuracy: 0.7500 - val_loss: 0.6756
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 320ms/step - accuracy: 0.5655 - loss: 0.6758 - val_accuracy: 0.6042 - val_loss: 0.6678
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - accuracy: 0.5487 - loss: 0.6825 - val_accuracy: 0.6042 - val_loss: 0.6550
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 326ms/step - accuracy: 0.5547 - loss: 0.6972 - val_accuracy: 0.5625 - val_loss: 0.6897
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 343ms/step - accuracy: 0.5694 - loss: 0.6888 - val_accuracy: 0.6146 - val_loss: 0.6786
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 290ms/step - accuracy: 0.5952 - loss: 0.6778 - val_accuracy: 0.5521 - val_loss: 0.6830
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 327ms/step - accuracy: 0.6242 - loss: 0.6579 - val_accuracy: 0.5000 - val_loss: 0.6943
# Epoch 12/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 292ms/step - accuracy: 0.6102 - loss: 0.6634 - val_accuracy: 0.7292 - val_loss: 0.6153
# Epoch 13/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 288ms/step - accuracy: 0.6418 - loss: 0.6321 - val_accuracy: 0.6562 - val_loss: 0.6402
# Epoch 14/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 342ms/step - accuracy: 0.6687 - loss: 0.6469 - val_accuracy: 0.6562 - val_loss: 0.6131
# Epoch 15/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - accuracy: 0.6422 - loss: 0.6264 - val_accuracy: 0.6875 - val_loss: 0.6368
# Epoch 16/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 324ms/step - accuracy: 0.6862 - loss: 0.5826 - val_accuracy: 0.6771 - val_loss: 0.6027
# Epoch 17/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - accuracy: 0.6896 - loss: 0.5955 - val_accuracy: 0.6667 - val_loss: 0.6071
# Epoch 18/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 421ms/step - accuracy: 0.7089 - loss: 0.5694 - val_accuracy: 0.7396 - val_loss: 0.5431
# Epoch 19/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 355ms/step - accuracy: 0.6755 - loss: 0.6177 - val_accuracy: 0.6771 - val_loss: 0.6587
# Epoch 20/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - accuracy: 0.6700 - loss: 0.6268 - val_accuracy: 0.4375 - val_loss: 0.6956
# Epoch 21/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 332ms/step - accuracy: 0.5424 - loss: 0.6631 - val_accuracy: 0.6458 - val_loss: 0.6277
# Epoch 22/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - accuracy: 0.6717 - loss: 0.5885 - val_accuracy: 0.8229 - val_loss: 0.4723
# Epoch 23/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 416ms/step - accuracy: 0.7132 - loss: 0.5696 - val_accuracy: 0.6562 - val_loss: 0.6575
# Epoch 24/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 361ms/step - accuracy: 0.6102 - loss: 0.6527 - val_accuracy: 0.8750 - val_loss: 0.4825
# Epoch 25/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 289ms/step - accuracy: 0.6768 - loss: 0.5726 - val_accuracy: 0.8125 - val_loss: 0.4935
# Epoch 26/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 320ms/step - accuracy: 0.7069 - loss: 0.5555 - val_accuracy: 0.6146 - val_loss: 0.7098
# Epoch 27/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 292ms/step - accuracy: 0.7255 - loss: 0.5776 - val_accuracy: 0.6979 - val_loss: 0.5634
# Epoch 28/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 325ms/step - accuracy: 0.7625 - loss: 0.4780 - val_accuracy: 0.7604 - val_loss: 0.5099
# Epoch 29/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 383ms/step - accuracy: 0.7545 - loss: 0.5103 - val_accuracy: 0.7083 - val_loss: 0.5328
# Epoch 30/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 296ms/step - accuracy: 0.7658 - loss: 0.4807 - val_accuracy: 0.7917 - val_loss: 0.4303
# Epoch 31/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 386ms/step - accuracy: 0.7616 - loss: 0.4698 - val_accuracy: 0.7188 - val_loss: 0.5121
# Epoch 32/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - accuracy: 0.7954 - loss: 0.4552 - val_accuracy: 0.7708 - val_loss: 0.4248
# Epoch 33/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 327ms/step - accuracy: 0.7989 - loss: 0.4639 - val_accuracy: 0.7188 - val_loss: 0.5932
# Epoch 34/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 311ms/step - accuracy: 0.7880 - loss: 0.4817 - val_accuracy: 0.7917 - val_loss: 0.4985
# Epoch 35/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 289ms/step - accuracy: 0.7800 - loss: 0.4540 - val_accuracy: 0.7708 - val_loss: 0.4425
# Epoch 36/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 327ms/step - accuracy: 0.8394 - loss: 0.3792 - val_accuracy: 0.8229 - val_loss: 0.4754
# Epoch 37/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - accuracy: 0.8219 - loss: 0.3829 - val_accuracy: 0.8229 - val_loss: 0.3280
# Epoch 38/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 322ms/step - accuracy: 0.8867 - loss: 0.2611 - val_accuracy: 0.8854 - val_loss: 0.3272
# Epoch 39/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 384ms/step - accuracy: 0.9107 - loss: 0.2557 - val_accuracy: 0.8958 - val_loss: 0.2651
# Epoch 40/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - accuracy: 0.9179 - loss: 0.2089 - val_accuracy: 0.9167 - val_loss: 0.1988
# Epoch 41/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 335ms/step - accuracy: 0.9520 - loss: 0.1355 - val_accuracy: 0.9479 - val_loss: 0.2056
# Epoch 42/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - accuracy: 0.9419 - loss: 0.1598 - val_accuracy: 0.9583 - val_loss: 0.1980
# Epoch 43/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 320ms/step - accuracy: 0.9599 - loss: 0.1365 - val_accuracy: 0.9688 - val_loss: 0.1044
# Epoch 44/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 384ms/step - accuracy: 0.9202 - loss: 0.1969 - val_accuracy: 0.9688 - val_loss: 0.1717
# Epoch 45/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 294ms/step - accuracy: 0.9722 - loss: 0.0874 - val_accuracy: 0.9271 - val_loss: 0.1833
# Epoch 46/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 348ms/step - accuracy: 0.9575 - loss: 0.1095 - val_accuracy: 0.9688 - val_loss: 0.0827
# Epoch 47/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 384ms/step - accuracy: 0.9259 - loss: 0.1793 - val_accuracy: 0.9062 - val_loss: 0.3028
# Epoch 48/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 302ms/step - accuracy: 0.8579 - loss: 0.4163 - val_accuracy: 0.9167 - val_loss: 0.2067
# Epoch 49/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 356ms/step - accuracy: 0.9675 - loss: 0.0910 - val_accuracy: 0.9688 - val_loss: 0.1450
# Epoch 50/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - accuracy: 0.9544 - loss: 0.0991 - val_accuracy: 0.9792 - val_loss: 0.1530

# %%
model.evaluate(test_dataset)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.9717 - loss: 0.1144
# [0.15611428022384644, 0.9682539701461792]

# %%
acc= history.history['accuracy']
val_acc = history.history['val_accuracy']

loss= history.history['loss']
val_loss = history.history['val_loss']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style
sns.set(style="whitegrid")

# Assuming you have already imported necessary libraries and have data for epochs, acc, val_acc, loss, and val_loss

plt.figure(figsize=(16, 8))  # Increase figure size for better visualization

# Subplot 1: Training and Validation Accuracy
plt.subplot(1, 2, 1)
sns.lineplot(x=range(epochs), y=acc, label='Training Accuracy', linewidth=2, color='blue')
sns.lineplot(x=range(epochs), y=val_acc, label='Validation Accuracy', linewidth=2, color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend(loc='lower right')
plt.grid(True)

# Subplot 2: Training and Validation Loss
plt.subplot(1, 2, 2)
sns.lineplot(x=range(epochs), y=loss, label='Training Loss', linewidth=2, color='blue')
sns.lineplot(x=range(epochs), y=val_loss, label='Validation Loss', linewidth=2, color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend(loc='upper right')
plt.grid(True)

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()
