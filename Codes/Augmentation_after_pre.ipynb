# %%
#THE AUGMENTATION IS DONE AFTER PREPROCESSING TO INCREASE THE DATASET
#AS WELL AS TO MAKE THE DATASET BALANCE

# %%
import os
import cv2
import math
import random
import shutil
import uuid
import time
import gc
import numpy as np
import pandas as pd
from tqdm import tqdm
from PIL import Image
from pathlib import Path
from glob import glob 
import matplotlib.pyplot as plt 
import tensorflow as tf
from collections import defaultdict
from imblearn.over_sampling import SMOTE
from sklearn.neighbors import NearestNeighbors
from sklearn.model_selection import train_test_split 
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img, load_img, save_img, ImageDataGenerator

imagegen = ImageDataGenerator()

# %%
base_path = "D:/final year project/Second Set/"
preprocessed_path1 = "D:/final year project/augmentation_after_pre/resized_dataset/"
preprocessed_path2 = "D:/final year project/augmentation_after_pre/denoised_dataset/"
preprocessed_path3 = "D:/final year project/augmentation_after_pre/normalized_dataset/"
preprocessed_path4 = "D:/final year project/augmentation_after_pre/enhanced_dataset/"
os.makedirs(preprocessed_path1, exist_ok=True)
os.makedirs(preprocessed_path2, exist_ok=True)
os.makedirs(preprocessed_path3, exist_ok=True)
os.makedirs(preprocessed_path4, exist_ok=True)

# %%
# RESIZE AUGMENTED IMAGES

TARGET_SIZE = (256, 256)

def resize_dataset(input_dir, output_dir):
    for class_name in ["400x Normal Oral Cavity Histopathological Images", "400x OSCC Histopathological Images"]:
        os.makedirs(os.path.join(output_dir, class_name), exist_ok=True)
        input_path = os.path.join(input_dir, class_name)
        output_path = os.path.join(output_dir, class_name)
        
        img_files = [f for f in os.listdir(input_path) if f.lower().endswith('.jpg')]
        
        for img_file in tqdm(img_files, desc=f"Resizing {class_name}"):
            try:
                img = cv2.imread(os.path.join(input_path, img_file))
                if img is not None:
                    resized = cv2.resize(img, TARGET_SIZE, interpolation=cv2.INTER_AREA)
                    cv2.imwrite(os.path.join(output_path, img_file), resized)
            except Exception:
                continue

print("Resizing images...")
resize_dataset(base_path, preprocessed_path1)
print(f"\nResizing complete. Output saved to: {preprocessed_path1}")
# Out:
# Resizing images...
# Resizing 400x Normal Oral Cavity Histopathological Images: 100%|█████████████████████████████████████████████████████████████████████| 201/201 [00:27<00:00,  7.38it/s]
# Resizing 400x OSCC Histopathological Images: 100%|███████████████████████████████████████████████████████████████████████████████████| 495/495 [01:11<00:00,  6.88it/s]
# Resizing complete. Output saved to: D:/final year project/augmentation_after_pre/resized_dataset/

# %%
#DENOISING:

# Wiener filter for a single channel 
def wiener_filter(img, kernel_size=3, noise_power=None):
    img = tf.cast(img, tf.float32)
    kernel = tf.ones((kernel_size, kernel_size, 1, 1)) / (kernel_size * kernel_size)
    mean = tf.nn.convolution(tf.expand_dims(img, axis=0), kernel, padding='SAME')
    mean = tf.squeeze(mean, axis=0)

    sqr_mean = tf.nn.convolution(tf.expand_dims(tf.square(img), axis=0), kernel, padding='SAME')
    sqr_mean = tf.squeeze(sqr_mean, axis=0)
    variance = sqr_mean - tf.square(mean)
    variance = tf.clip_by_value(variance, 0.0, tf.float32.max)

    gain = variance / (variance + noise_power)
    filtered_img = mean + gain * (img - mean)
    return filtered_img

# Apply Wiener filter channel-wise for color images
def wiener_filter_color(image, kernel_size=3, noise_power=None):
    channels = tf.unstack(image, axis=-1)
    filtered_channels = [
        # Squeeze the channel dimension after filtering
        tf.squeeze(wiener_filter(tf.expand_dims(c, axis=-1), kernel_size, noise_power), axis=-1)
        for c in channels
    ]
    return tf.stack(filtered_channels, axis=-1)

# %%
import os
#Check noise median: 
def estimate_noise_mad_rgb(img_path):
    img = cv2.imread(img_path, cv2.IMREAD_COLOR).astype(np.float32) / 255.0
    noise_vars = []
    for c in range(3): 
        channel = img[..., c]
        grad = cv2.Laplacian(channel, cv2.CV_32F)
        sigma = np.median(np.abs(grad - np.median(grad))) / 0.6745
        noise_vars.append(sigma ** 2)
    return np.mean(noise_vars)

#Denoise function:
def denoise_dataset(input_dir, output_dir, kernel_size=3):

    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Get all class folders
    class_folders = [d for d in os.listdir(input_dir) if os.path.isdir(os.path.join(input_dir, d))]
    
    for class_name in tqdm(class_folders, desc="Processing classes"):
        class_input_dir = os.path.join(input_dir, class_name)
        class_output_dir = os.path.join(output_dir, class_name)
        os.makedirs(class_output_dir, exist_ok=True)
        
        # Get all images in class folder
        image_files = [f for f in os.listdir(class_input_dir) 
                      if f.lower().endswith(('.jpg'))]
        
        for img_file in tqdm(image_files, desc=f"Processing {class_name}", leave=False):
            img_path = os.path.join(class_input_dir, img_file)
            
            # Load and normalize image
            img = cv2.imread(img_path)
            if img is None:
                print(f"Warning: Could not read image {img_path}")
                continue

             # Estimate noise for this image
            noise_var = estimate_noise_mad_rgb(img_path)
            # print(f"Noise variance (MAD): {noise_var:.6f}")
            img = img.astype(np.float32) / 255.0
            img_tensor = tf.convert_to_tensor(img)
            
            # Apply Wiener filter
            filtered = wiener_filter_color(img_tensor, kernel_size=kernel_size, noise_power=noise_var)
            filtered_img = (filtered.numpy() * 255).astype(np.uint8)
            
            # Save result
            output_path = os.path.join(class_output_dir, img_file)
            cv2.imwrite(output_path, filtered_img)

if __name__ == "__main__":
    denoise_dataset(preprocessed_path1, preprocessed_path2)
# Out:
# Processing classes:   0%|                                                                                                                        | 0/2 [00:00<?, ?it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:   0%|                                                                             | 0/201 [00:00<?, ?it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:   0%|▎                                                                    | 1/201 [00:00<01:06,  3.01it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:   1%|▋                                                                    | 2/201 [00:02<03:54,  1.18s/it]
# Processing 400x Normal Oral Cavity Histopathological Images:   1%|█                                                                    | 3/201 [00:02<02:25,  1.36it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:   2%|█▋                                                                   | 5/201 [00:02<01:08,  2.86it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:   3%|██▍                                                                  | 7/201 [00:02<00:42,  4.59it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:   4%|███                                                                  | 9/201 [00:02<00:29,  6.50it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:   6%|████                                                                | 12/201 [00:02<00:19,  9.82it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:   7%|█████                                                               | 15/201 [00:02<00:14, 12.80it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:   9%|██████                                                              | 18/201 [00:03<00:14, 12.60it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  10%|██████▊                                                             | 20/201 [00:03<00:13, 13.64it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  11%|███████▊                                                            | 23/201 [00:03<00:11, 15.58it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  13%|████████▊                                                           | 26/201 [00:03<00:10, 17.42it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  14%|█████████▊                                                          | 29/201 [00:03<00:08, 19.49it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  16%|██████████▊                                                         | 32/201 [00:03<00:08, 20.39it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  17%|███████████▊                                                        | 35/201 [00:03<00:08, 19.43it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  19%|████████████▊                                                       | 38/201 [00:04<00:08, 19.69it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  20%|█████████████▊                                                      | 41/201 [00:04<00:08, 19.16it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  22%|██████████████▉                                                     | 44/201 [00:04<00:07, 19.67it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  23%|███████████████▉                                                    | 47/201 [00:04<00:08, 18.47it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  25%|████████████████▉                                                   | 50/201 [00:04<00:07, 19.30it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  26%|█████████████████▉                                                  | 53/201 [00:04<00:07, 20.91it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  28%|██████████████████▉                                                 | 56/201 [00:04<00:06, 21.31it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  29%|███████████████████▉                                                | 59/201 [00:05<00:06, 21.21it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  31%|████████████████████▉                                               | 62/201 [00:05<00:06, 20.87it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  32%|█████████████████████▉                                              | 65/201 [00:05<00:06, 22.21it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  34%|███████████████████████                                             | 68/201 [00:05<00:05, 22.86it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  35%|████████████████████████                                            | 71/201 [00:05<00:06, 21.30it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  37%|█████████████████████████                                           | 74/201 [00:05<00:05, 22.50it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  38%|██████████████████████████                                          | 77/201 [00:05<00:05, 23.55it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  40%|███████████████████████████                                         | 80/201 [00:06<00:05, 24.11it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  41%|████████████████████████████                                        | 83/201 [00:06<00:04, 25.00it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  43%|█████████████████████████████                                       | 86/201 [00:06<00:04, 24.87it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  44%|██████████████████████████████                                      | 89/201 [00:06<00:04, 24.20it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  46%|███████████████████████████████                                     | 92/201 [00:06<00:04, 24.58it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  47%|████████████████████████████████▏                                   | 95/201 [00:06<00:04, 25.29it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  49%|█████████████████████████████████▏                                  | 98/201 [00:06<00:04, 23.58it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  50%|█████████████████████████████████▋                                 | 101/201 [00:06<00:04, 23.92it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  52%|██████████████████████████████████▋                                | 104/201 [00:06<00:04, 23.94it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  53%|███████████████████████████████████▋                               | 107/201 [00:07<00:04, 20.69it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  55%|████████████████████████████████████▋                              | 110/201 [00:07<00:04, 19.13it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  56%|█████████████████████████████████████▋                             | 113/201 [00:07<00:04, 19.19it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  58%|██████████████████████████████████████▋                            | 116/201 [00:07<00:04, 20.70it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  59%|███████████████████████████████████████▋                           | 119/201 [00:07<00:04, 20.30it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  61%|████████████████████████████████████████▋                          | 122/201 [00:07<00:03, 21.83it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  62%|█████████████████████████████████████████▋                         | 125/201 [00:08<00:03, 22.45it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  64%|██████████████████████████████████████████▋                        | 128/201 [00:08<00:03, 22.69it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  65%|███████████████████████████████████████████▋                       | 131/201 [00:08<00:02, 23.60it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  67%|████████████████████████████████████████████▋                      | 134/201 [00:08<00:02, 23.89it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  68%|█████████████████████████████████████████████▋                     | 137/201 [00:08<00:02, 23.53it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  70%|██████████████████████████████████████████████▋                    | 140/201 [00:08<00:02, 23.12it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  71%|███████████████████████████████████████████████▋                   | 143/201 [00:08<00:02, 23.17it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  73%|████████████████████████████████████████████████▋                  | 146/201 [00:08<00:02, 22.53it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  74%|█████████████████████████████████████████████████▋                 | 149/201 [00:09<00:02, 23.71it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  76%|██████████████████████████████████████████████████▋                | 152/201 [00:09<00:01, 24.74it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  77%|███████████████████████████████████████████████████▋               | 155/201 [00:09<00:01, 25.29it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  79%|████████████████████████████████████████████████████▋              | 158/201 [00:09<00:01, 24.57it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  80%|█████████████████████████████████████████████████████▋             | 161/201 [00:09<00:01, 23.42it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  82%|██████████████████████████████████████████████████████▋            | 164/201 [00:09<00:01, 23.19it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  83%|███████████████████████████████████████████████████████▋           | 167/201 [00:09<00:01, 23.87it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  85%|████████████████████████████████████████████████████████▋          | 170/201 [00:09<00:01, 20.47it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  86%|█████████████████████████████████████████████████████████▋         | 173/201 [00:10<00:01, 21.65it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  88%|██████████████████████████████████████████████████████████▋        | 176/201 [00:10<00:01, 22.56it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  89%|███████████████████████████████████████████████████████████▋       | 179/201 [00:10<00:01, 21.56it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  91%|████████████████████████████████████████████████████████████▋      | 182/201 [00:10<00:00, 21.94it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  92%|█████████████████████████████████████████████████████████████▋     | 185/201 [00:10<00:00, 22.57it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  94%|██████████████████████████████████████████████████████████████▋    | 188/201 [00:10<00:00, 22.71it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  95%|███████████████████████████████████████████████████████████████▋   | 191/201 [00:10<00:00, 22.54it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  97%|████████████████████████████████████████████████████████████████▋  | 194/201 [00:11<00:00, 20.98it/s]
# Processing 400x Normal Oral Cavity Histopathological Images:  98%|█████████████████████████████████████████████████████████████████▋ | 197/201 [00:11<00:00, 16.75it/s]
# Processing 400x Normal Oral Cavity Histopathological Images: 100%|██████████████████████████████████████████████████████████████████▋| 200/201 [00:11<00:00, 18.68it/s]
# Processing classes:  50%|████████████████████████████████████████████████████████                                                        | 1/2 [00:11<00:11, 11.49s/it]
# Processing 400x OSCC Histopathological Images:   0%|                                                                                           | 0/495 [00:00<?, ?it/s]
# Processing 400x OSCC Histopathological Images:   1%|▌                                                                                  | 3/495 [00:00<00:18, 26.42it/s]
# Processing 400x OSCC Histopathological Images:   1%|█                                                                                  | 6/495 [00:00<00:21, 23.21it/s]
# Processing 400x OSCC Histopathological Images:   2%|█▌                                                                                 | 9/495 [00:00<00:19, 24.76it/s]
# Processing 400x OSCC Histopathological Images:   2%|█▉                                                                                | 12/495 [00:00<00:19, 24.94it/s]
# Processing 400x OSCC Histopathological Images:   3%|██▍                                                                               | 15/495 [00:00<00:19, 24.96it/s]
# Processing 400x OSCC Histopathological Images:   4%|██▉                                                                               | 18/495 [00:00<00:18, 25.31it/s]
# Processing 400x OSCC Histopathological Images:   4%|███▍                                                                              | 21/495 [00:00<00:20, 22.99it/s]
# Processing 400x OSCC Histopathological Images:   5%|███▉                                                                              | 24/495 [00:00<00:19, 23.94it/s]
# Processing 400x OSCC Histopathological Images:   5%|████▍                                                                             | 27/495 [00:01<00:23, 19.65it/s]
# Processing 400x OSCC Histopathological Images:   6%|████▉                                                                             | 30/495 [00:01<00:21, 21.23it/s]
# Processing 400x OSCC Histopathological Images:   7%|█████▍                                                                            | 33/495 [00:01<00:20, 22.44it/s]
# Processing 400x OSCC Histopathological Images:   7%|█████▉                                                                            | 36/495 [00:01<00:19, 23.24it/s]
# Processing 400x OSCC Histopathological Images:   8%|██████▍                                                                           | 39/495 [00:01<00:19, 22.92it/s]
# Processing 400x OSCC Histopathological Images:   8%|██████▉                                                                           | 42/495 [00:01<00:19, 23.60it/s]
# Processing 400x OSCC Histopathological Images:   9%|███████▍                                                                          | 45/495 [00:02<00:24, 18.25it/s]
# Processing 400x OSCC Histopathological Images:  10%|███████▉                                                                          | 48/495 [00:02<00:23, 19.25it/s]
# Processing 400x OSCC Histopathological Images:  10%|████████▍                                                                         | 51/495 [00:02<00:21, 20.44it/s]
# Processing 400x OSCC Histopathological Images:  11%|████████▉                                                                         | 54/495 [00:02<00:21, 20.41it/s]
# Processing 400x OSCC Histopathological Images:  12%|█████████▍                                                                        | 57/495 [00:02<00:20, 21.59it/s]
# Processing 400x OSCC Histopathological Images:  12%|█████████▉                                                                        | 60/495 [00:02<00:20, 21.72it/s]
# Processing 400x OSCC Histopathological Images:  13%|██████████▍                                                                       | 63/495 [00:02<00:19, 22.58it/s]
# Processing 400x OSCC Histopathological Images:  13%|██████████▉                                                                       | 66/495 [00:02<00:19, 21.73it/s]
# Processing 400x OSCC Histopathological Images:  14%|███████████▍                                                                      | 69/495 [00:03<00:18, 22.69it/s]
# Processing 400x OSCC Histopathological Images:  15%|███████████▉                                                                      | 72/495 [00:03<00:18, 23.33it/s]
# Processing 400x OSCC Histopathological Images:  15%|████████████▍                                                                     | 75/495 [00:03<00:17, 23.50it/s]
# Processing 400x OSCC Histopathological Images:  16%|████████████▉                                                                     | 78/495 [00:03<00:18, 22.86it/s]
# Processing 400x OSCC Histopathological Images:  16%|█████████████▍                                                                    | 81/495 [00:03<00:18, 22.64it/s]
# Processing 400x OSCC Histopathological Images:  17%|█████████████▉                                                                    | 84/495 [00:03<00:18, 21.92it/s]
# Processing 400x OSCC Histopathological Images:  18%|██████████████▍                                                                   | 87/495 [00:03<00:19, 20.66it/s]
# Processing 400x OSCC Histopathological Images:  18%|██████████████▉                                                                   | 90/495 [00:04<00:20, 20.07it/s]
# Processing 400x OSCC Histopathological Images:  19%|███████████████▍                                                                  | 93/495 [00:04<00:19, 20.35it/s]
# Processing 400x OSCC Histopathological Images:  19%|███████████████▉                                                                  | 96/495 [00:04<00:20, 19.14it/s]
# Processing 400x OSCC Histopathological Images:  20%|████████████████▏                                                                 | 98/495 [00:04<00:20, 19.01it/s]
# Processing 400x OSCC Histopathological Images:  20%|████████████████▌                                                                | 101/495 [00:04<00:19, 19.91it/s]
# Processing 400x OSCC Histopathological Images:  21%|█████████████████                                                                | 104/495 [00:04<00:18, 20.65it/s]
# Processing 400x OSCC Histopathological Images:  22%|█████████████████▌                                                               | 107/495 [00:04<00:19, 20.36it/s]
# Processing 400x OSCC Histopathological Images:  22%|██████████████████                                                               | 110/495 [00:05<00:18, 21.05it/s]
# Processing 400x OSCC Histopathological Images:  23%|██████████████████▍                                                              | 113/495 [00:05<00:17, 21.81it/s]
# Processing 400x OSCC Histopathological Images:  23%|██████████████████▉                                                              | 116/495 [00:05<00:16, 23.23it/s]
# Processing 400x OSCC Histopathological Images:  24%|███████████████████▍                                                             | 119/495 [00:05<00:15, 23.80it/s]
# Processing 400x OSCC Histopathological Images:  25%|███████████████████▉                                                             | 122/495 [00:05<00:15, 24.11it/s]
# Processing 400x OSCC Histopathological Images:  25%|████████████████████▍                                                            | 125/495 [00:05<00:15, 24.36it/s]
# Processing 400x OSCC Histopathological Images:  26%|████████████████████▉                                                            | 128/495 [00:05<00:14, 24.59it/s]
# Processing 400x OSCC Histopathological Images:  26%|█████████████████████▍                                                           | 131/495 [00:05<00:15, 23.82it/s]
# Processing 400x OSCC Histopathological Images:  27%|█████████████████████▉                                                           | 134/495 [00:06<00:15, 23.28it/s]
# Processing 400x OSCC Histopathological Images:  28%|██████████████████████▍                                                          | 137/495 [00:06<00:14, 23.91it/s]
# Processing 400x OSCC Histopathological Images:  28%|██████████████████████▉                                                          | 140/495 [00:06<00:14, 24.49it/s]
# Processing 400x OSCC Histopathological Images:  29%|███████████████████████▍                                                         | 143/495 [00:06<00:14, 24.89it/s]
# Processing 400x OSCC Histopathological Images:  29%|███████████████████████▉                                                         | 146/495 [00:06<00:17, 19.40it/s]
# Processing 400x OSCC Histopathological Images:  30%|████████████████████████▍                                                        | 149/495 [00:06<00:16, 20.79it/s]
# Processing 400x OSCC Histopathological Images:  31%|████████████████████████▊                                                        | 152/495 [00:06<00:15, 21.69it/s]
# Processing 400x OSCC Histopathological Images:  31%|█████████████████████████▎                                                       | 155/495 [00:07<00:14, 22.67it/s]
# Processing 400x OSCC Histopathological Images:  32%|█████████████████████████▊                                                       | 158/495 [00:07<00:14, 22.77it/s]
# Processing 400x OSCC Histopathological Images:  33%|██████████████████████████▎                                                      | 161/495 [00:07<00:16, 20.22it/s]
# Processing 400x OSCC Histopathological Images:  33%|██████████████████████████▊                                                      | 164/495 [00:07<00:15, 21.52it/s]
# Processing 400x OSCC Histopathological Images:  34%|███████████████████████████▎                                                     | 167/495 [00:08<00:44,  7.31it/s]
# Processing 400x OSCC Histopathological Images:  34%|███████████████████████████▊                                                     | 170/495 [00:08<00:34,  9.30it/s]
# Processing 400x OSCC Histopathological Images:  35%|████████████████████████████▎                                                    | 173/495 [00:08<00:28, 11.47it/s]
# Processing 400x OSCC Histopathological Images:  36%|████████████████████████████▊                                                    | 176/495 [00:08<00:23, 13.71it/s]
# Processing 400x OSCC Histopathological Images:  36%|█████████████████████████████▎                                                   | 179/495 [00:08<00:20, 15.38it/s]
# Processing 400x OSCC Histopathological Images:  37%|█████████████████████████████▊                                                   | 182/495 [00:09<00:18, 16.68it/s]
# Processing 400x OSCC Histopathological Images:  37%|██████████████████████████████▎                                                  | 185/495 [00:09<00:19, 15.84it/s]
# Processing 400x OSCC Histopathological Images:  38%|██████████████████████████████▊                                                  | 188/495 [00:09<00:17, 17.71it/s]
# Processing 400x OSCC Histopathological Images:  39%|███████████████████████████████▎                                                 | 191/495 [00:09<00:19, 15.97it/s]
# Processing 400x OSCC Histopathological Images:  39%|███████████████████████████████▌                                                 | 193/495 [00:09<00:18, 16.62it/s]
# Processing 400x OSCC Histopathological Images:  40%|████████████████████████████████                                                 | 196/495 [00:09<00:16, 18.44it/s]
# Processing 400x OSCC Histopathological Images:  40%|████████████████████████████████▌                                                | 199/495 [00:10<00:14, 19.99it/s]
# Processing 400x OSCC Histopathological Images:  41%|█████████████████████████████████                                                | 202/495 [00:10<00:13, 21.03it/s]
# Processing 400x OSCC Histopathological Images:  41%|█████████████████████████████████▌                                               | 205/495 [00:10<00:13, 21.56it/s]
# Processing 400x OSCC Histopathological Images:  42%|██████████████████████████████████                                               | 208/495 [00:10<00:13, 20.91it/s]
# Processing 400x OSCC Histopathological Images:  43%|██████████████████████████████████▌                                              | 211/495 [00:10<00:14, 19.60it/s]
# Processing 400x OSCC Histopathological Images:  43%|███████████████████████████████████                                              | 214/495 [00:10<00:14, 19.43it/s]
# Processing 400x OSCC Histopathological Images:  44%|███████████████████████████████████▎                                             | 216/495 [00:10<00:14, 19.27it/s]
# Processing 400x OSCC Histopathological Images:  44%|███████████████████████████████████▋                                             | 218/495 [00:11<00:15, 17.42it/s]
# Processing 400x OSCC Histopathological Images:  44%|████████████████████████████████████                                             | 220/495 [00:11<00:15, 17.31it/s]
# Processing 400x OSCC Histopathological Images:  45%|████████████████████████████████████▍                                            | 223/495 [00:11<00:14, 18.56it/s]
# Processing 400x OSCC Histopathological Images:  45%|████████████████████████████████████▊                                            | 225/495 [00:11<00:16, 16.10it/s]
# Processing 400x OSCC Histopathological Images:  46%|█████████████████████████████████████▏                                           | 227/495 [00:11<00:16, 16.28it/s]
# Processing 400x OSCC Histopathological Images:  46%|█████████████████████████████████████▋                                           | 230/495 [00:11<00:14, 17.91it/s]
# Processing 400x OSCC Histopathological Images:  47%|██████████████████████████████████████▏                                          | 233/495 [00:11<00:13, 19.46it/s]
# Processing 400x OSCC Histopathological Images:  48%|██████████████████████████████████████▌                                          | 236/495 [00:12<00:14, 17.92it/s]
# Processing 400x OSCC Histopathological Images:  48%|███████████████████████████████████████                                          | 239/495 [00:12<00:12, 19.92it/s]
# Processing 400x OSCC Histopathological Images:  49%|███████████████████████████████████████▌                                         | 242/495 [00:12<00:12, 20.88it/s]
# Processing 400x OSCC Histopathological Images:  49%|████████████████████████████████████████                                         | 245/495 [00:12<00:11, 21.58it/s]
# Processing 400x OSCC Histopathological Images:  50%|████████████████████████████████████████▌                                        | 248/495 [00:12<00:11, 22.34it/s]
# Processing 400x OSCC Histopathological Images:  51%|█████████████████████████████████████████                                        | 251/495 [00:12<00:11, 21.52it/s]
# Processing 400x OSCC Histopathological Images:  51%|█████████████████████████████████████████▌                                       | 254/495 [00:12<00:11, 20.80it/s]
# Processing 400x OSCC Histopathological Images:  52%|██████████████████████████████████████████                                       | 257/495 [00:13<00:11, 20.45it/s]
# Processing 400x OSCC Histopathological Images:  53%|██████████████████████████████████████████▌                                      | 260/495 [00:13<00:13, 17.12it/s]
# Processing 400x OSCC Histopathological Images:  53%|███████████████████████████████████████████                                      | 263/495 [00:13<00:12, 18.38it/s]
# Processing 400x OSCC Histopathological Images:  54%|███████████████████████████████████████████▌                                     | 266/495 [00:13<00:11, 19.68it/s]
# Processing 400x OSCC Histopathological Images:  54%|████████████████████████████████████████████                                     | 269/495 [00:13<00:11, 20.49it/s]
# Processing 400x OSCC Histopathological Images:  55%|████████████████████████████████████████████▌                                    | 272/495 [00:13<00:11, 19.69it/s]
# Processing 400x OSCC Histopathological Images:  56%|█████████████████████████████████████████████                                    | 275/495 [00:14<00:12, 18.02it/s]
# Processing 400x OSCC Histopathological Images:  56%|█████████████████████████████████████████████▍                                   | 278/495 [00:14<00:11, 18.87it/s]
# Processing 400x OSCC Histopathological Images:  57%|█████████████████████████████████████████████▊                                   | 280/495 [00:14<00:11, 18.64it/s]
# Processing 400x OSCC Histopathological Images:  57%|██████████████████████████████████████████████▎                                  | 283/495 [00:14<00:10, 20.01it/s]
# Processing 400x OSCC Histopathological Images:  58%|██████████████████████████████████████████████▊                                  | 286/495 [00:14<00:09, 21.37it/s]
# Processing 400x OSCC Histopathological Images:  58%|███████████████████████████████████████████████▎                                 | 289/495 [00:14<00:09, 22.86it/s]
# Processing 400x OSCC Histopathological Images:  59%|███████████████████████████████████████████████▊                                 | 292/495 [00:14<00:11, 17.50it/s]
# Processing 400x OSCC Histopathological Images:  60%|████████████████████████████████████████████████▎                                | 295/495 [00:15<00:10, 18.81it/s]
# Processing 400x OSCC Histopathological Images:  60%|████████████████████████████████████████████████▊                                | 298/495 [00:15<00:10, 19.29it/s]
# Processing 400x OSCC Histopathological Images:  61%|█████████████████████████████████████████████████▎                               | 301/495 [00:15<00:09, 19.60it/s]
# Processing 400x OSCC Histopathological Images:  61%|█████████████████████████████████████████████████▋                               | 304/495 [00:15<00:09, 20.70it/s]
# Processing 400x OSCC Histopathological Images:  62%|██████████████████████████████████████████████████▏                              | 307/495 [00:15<00:08, 21.97it/s]
# Processing 400x OSCC Histopathological Images:  63%|██████████████████████████████████████████████████▋                              | 310/495 [00:15<00:08, 21.36it/s]
# Processing 400x OSCC Histopathological Images:  63%|███████████████████████████████████████████████████▏                             | 313/495 [00:15<00:08, 22.11it/s]
# Processing 400x OSCC Histopathological Images:  64%|███████████████████████████████████████████████████▋                             | 316/495 [00:16<00:09, 19.29it/s]
# Processing 400x OSCC Histopathological Images:  64%|████████████████████████████████████████████████████▏                            | 319/495 [00:16<00:09, 17.76it/s]
# Processing 400x OSCC Histopathological Images:  65%|████████████████████████████████████████████████████▋                            | 322/495 [00:16<00:09, 18.15it/s]
# Processing 400x OSCC Histopathological Images:  66%|█████████████████████████████████████████████████████▏                           | 325/495 [00:16<00:08, 19.65it/s]
# Processing 400x OSCC Histopathological Images:  66%|█████████████████████████████████████████████████████▋                           | 328/495 [00:16<00:07, 20.95it/s]
# Processing 400x OSCC Histopathological Images:  67%|██████████████████████████████████████████████████████▏                          | 331/495 [00:16<00:07, 21.55it/s]
# Processing 400x OSCC Histopathological Images:  67%|██████████████████████████████████████████████████████▋                          | 334/495 [00:16<00:07, 21.42it/s]
# Processing 400x OSCC Histopathological Images:  68%|███████████████████████████████████████████████████████▏                         | 337/495 [00:17<00:08, 18.72it/s]
# Processing 400x OSCC Histopathological Images:  68%|███████████████████████████████████████████████████████▍                         | 339/495 [00:17<00:08, 18.93it/s]
# Processing 400x OSCC Histopathological Images:  69%|███████████████████████████████████████████████████████▊                         | 341/495 [00:17<00:08, 18.87it/s]
# Processing 400x OSCC Histopathological Images:  69%|████████████████████████████████████████████████████████▏                        | 343/495 [00:17<00:07, 19.03it/s]
# Processing 400x OSCC Histopathological Images:  70%|████████████████████████████████████████████████████████▍                        | 345/495 [00:17<00:09, 15.21it/s]
# Processing 400x OSCC Histopathological Images:  70%|████████████████████████████████████████████████████████▊                        | 347/495 [00:17<00:09, 16.05it/s]
# Processing 400x OSCC Histopathological Images:  71%|█████████████████████████████████████████████████████████                        | 349/495 [00:17<00:10, 14.55it/s]
# Processing 400x OSCC Histopathological Images:  71%|█████████████████████████████████████████████████████████▌                       | 352/495 [00:18<00:08, 16.81it/s]
# Processing 400x OSCC Histopathological Images:  72%|██████████████████████████████████████████████████████████                       | 355/495 [00:18<00:07, 18.87it/s]
# Processing 400x OSCC Histopathological Images:  72%|██████████████████████████████████████████████████████████▌                      | 358/495 [00:18<00:06, 20.01it/s]
# Processing 400x OSCC Histopathological Images:  73%|███████████████████████████████████████████████████████████                      | 361/495 [00:18<00:07, 18.97it/s]
# Processing 400x OSCC Histopathological Images:  73%|███████████████████████████████████████████████████████████▍                     | 363/495 [00:18<00:06, 19.11it/s]
# Processing 400x OSCC Histopathological Images:  74%|███████████████████████████████████████████████████████████▋                     | 365/495 [00:18<00:07, 17.96it/s]
# Processing 400x OSCC Histopathological Images:  74%|████████████████████████████████████████████████████████████                     | 367/495 [00:19<00:10, 11.70it/s]
# Processing 400x OSCC Histopathological Images:  75%|████████████████████████████████████████████████████████████▍                    | 369/495 [00:19<00:10, 11.80it/s]
# Processing 400x OSCC Histopathological Images:  75%|████████████████████████████████████████████████████████████▋                    | 371/495 [00:19<00:09, 12.75it/s]
# Processing 400x OSCC Histopathological Images:  76%|█████████████████████████████████████████████████████████████▏                   | 374/495 [00:19<00:08, 15.03it/s]
# Processing 400x OSCC Histopathological Images:  76%|█████████████████████████████████████████████████████████████▌                   | 376/495 [00:19<00:07, 15.91it/s]
# Processing 400x OSCC Histopathological Images:  76%|█████████████████████████████████████████████████████████████▊                   | 378/495 [00:19<00:07, 16.65it/s]
# Processing 400x OSCC Histopathological Images:  77%|██████████████████████████████████████████████████████████████▏                  | 380/495 [00:19<00:07, 14.39it/s]
# Processing 400x OSCC Histopathological Images:  77%|██████████████████████████████████████████████████████████████▌                  | 382/495 [00:20<00:09, 12.13it/s]
# Processing 400x OSCC Histopathological Images:  78%|██████████████████████████████████████████████████████████████▊                  | 384/495 [00:20<00:10, 10.20it/s]
# Processing 400x OSCC Histopathological Images:  78%|███████████████████████████████████████████████████████████████▏                 | 386/495 [00:20<00:09, 11.89it/s]
# Processing 400x OSCC Histopathological Images:  78%|███████████████████████████████████████████████████████████████▍                 | 388/495 [00:20<00:08, 12.94it/s]
# Processing 400x OSCC Histopathological Images:  79%|███████████████████████████████████████████████████████████████▊                 | 390/495 [00:20<00:07, 13.89it/s]
# Processing 400x OSCC Histopathological Images:  79%|████████████████████████████████████████████████████████████████▏                | 392/495 [00:20<00:07, 14.62it/s]
# Processing 400x OSCC Histopathological Images:  80%|████████████████████████████████████████████████████████████████▍                | 394/495 [00:20<00:06, 14.55it/s]
# Processing 400x OSCC Histopathological Images:  80%|████████████████████████████████████████████████████████████████▊                | 396/495 [00:21<00:06, 15.44it/s]
# Processing 400x OSCC Histopathological Images:  80%|█████████████████████████████████████████████████████████████████▏               | 398/495 [00:21<00:06, 15.92it/s]
# Processing 400x OSCC Histopathological Images:  81%|█████████████████████████████████████████████████████████████████▍               | 400/495 [00:21<00:05, 16.69it/s]
# Processing 400x OSCC Histopathological Images:  81%|█████████████████████████████████████████████████████████████████▊               | 402/495 [00:21<00:05, 17.37it/s]
# Processing 400x OSCC Histopathological Images:  82%|██████████████████████████████████████████████████████████████████               | 404/495 [00:21<00:05, 17.92it/s]
# Processing 400x OSCC Histopathological Images:  82%|██████████████████████████████████████████████████████████████████▍              | 406/495 [00:21<00:06, 14.49it/s]
# Processing 400x OSCC Histopathological Images:  82%|██████████████████████████████████████████████████████████████████▊              | 408/495 [00:21<00:05, 15.48it/s]
# Processing 400x OSCC Histopathological Images:  83%|███████████████████████████████████████████████████████████████████▎             | 411/495 [00:21<00:04, 17.61it/s]
# Processing 400x OSCC Histopathological Images:  84%|███████████████████████████████████████████████████████████████████▋             | 414/495 [00:22<00:04, 19.04it/s]
# Processing 400x OSCC Histopathological Images:  84%|████████████████████████████████████████████████████████████████████▏            | 417/495 [00:22<00:03, 19.96it/s]
# Processing 400x OSCC Histopathological Images:  85%|████████████████████████████████████████████████████████████████████▋            | 420/495 [00:22<00:03, 20.13it/s]
# Processing 400x OSCC Histopathological Images:  85%|█████████████████████████████████████████████████████████████████████▏           | 423/495 [00:22<00:03, 20.69it/s]
# Processing 400x OSCC Histopathological Images:  86%|█████████████████████████████████████████████████████████████████████▋           | 426/495 [00:22<00:03, 20.99it/s]
# Processing 400x OSCC Histopathological Images:  87%|██████████████████████████████████████████████████████████████████████▏          | 429/495 [00:22<00:03, 19.82it/s]
# Processing 400x OSCC Histopathological Images:  87%|██████████████████████████████████████████████████████████████████████▋          | 432/495 [00:23<00:04, 15.44it/s]
# Processing 400x OSCC Histopathological Images:  88%|███████████████████████████████████████████████████████████████████████▏         | 435/495 [00:23<00:03, 16.81it/s]
# Processing 400x OSCC Histopathological Images:  88%|███████████████████████████████████████████████████████████████████████▋         | 438/495 [00:23<00:03, 18.30it/s]
# Processing 400x OSCC Histopathological Images:  89%|████████████████████████████████████████████████████████████████████████▏        | 441/495 [00:23<00:02, 19.51it/s]
# Processing 400x OSCC Histopathological Images:  90%|████████████████████████████████████████████████████████████████████████▋        | 444/495 [00:23<00:02, 19.62it/s]
# Processing 400x OSCC Histopathological Images:  90%|█████████████████████████████████████████████████████████████████████████▏       | 447/495 [00:23<00:02, 19.17it/s]
# Processing 400x OSCC Histopathological Images:  91%|█████████████████████████████████████████████████████████████████████████▍       | 449/495 [00:23<00:02, 19.32it/s]
# Processing 400x OSCC Histopathological Images:  91%|█████████████████████████████████████████████████████████████████████████▊       | 451/495 [00:24<00:02, 17.52it/s]
# Processing 400x OSCC Histopathological Images:  92%|██████████████████████████████████████████████████████████████████████████▏      | 453/495 [00:24<00:02, 16.40it/s]
# Processing 400x OSCC Histopathological Images:  92%|██████████████████████████████████████████████████████████████████████████▍      | 455/495 [00:24<00:03, 10.87it/s]
# Processing 400x OSCC Histopathological Images:  92%|██████████████████████████████████████████████████████████████████████████▊      | 457/495 [00:24<00:04,  9.25it/s]
# Processing 400x OSCC Histopathological Images:  93%|███████████████████████████████████████████████████████████████████████████      | 459/495 [00:25<00:03, 10.06it/s]
# Processing 400x OSCC Histopathological Images:  93%|███████████████████████████████████████████████████████████████████████████▍     | 461/495 [00:25<00:02, 11.68it/s]
# Processing 400x OSCC Histopathological Images:  94%|███████████████████████████████████████████████████████████████████████████▉     | 464/495 [00:25<00:02, 14.20it/s]
# Processing 400x OSCC Histopathological Images:  94%|████████████████████████████████████████████████████████████████████████████▎    | 466/495 [00:25<00:02, 14.49it/s]
# Processing 400x OSCC Histopathological Images:  95%|████████████████████████████████████████████████████████████████████████████▌    | 468/495 [00:25<00:01, 13.90it/s]
# Processing 400x OSCC Histopathological Images:  95%|████████████████████████████████████████████████████████████████████████████▉    | 470/495 [00:25<00:02, 11.86it/s]
# Processing 400x OSCC Histopathological Images:  95%|█████████████████████████████████████████████████████████████████████████████▏   | 472/495 [00:25<00:01, 12.01it/s]
# Processing 400x OSCC Histopathological Images:  96%|█████████████████████████████████████████████████████████████████████████████▌   | 474/495 [00:26<00:01, 12.32it/s]
# Processing 400x OSCC Histopathological Images:  96%|█████████████████████████████████████████████████████████████████████████████▉   | 476/495 [00:26<00:01, 13.45it/s]
# Processing 400x OSCC Histopathological Images:  97%|██████████████████████████████████████████████████████████████████████████████▏  | 478/495 [00:26<00:01, 13.10it/s]
# Processing 400x OSCC Histopathological Images:  97%|██████████████████████████████████████████████████████████████████████████████▌  | 480/495 [00:26<00:01, 13.45it/s]
# Processing 400x OSCC Histopathological Images:  97%|██████████████████████████████████████████████████████████████████████████████▊  | 482/495 [00:26<00:00, 13.80it/s]
# Processing 400x OSCC Histopathological Images:  98%|███████████████████████████████████████████████████████████████████████████████▏ | 484/495 [00:26<00:00, 14.84it/s]
# Processing 400x OSCC Histopathological Images:  98%|███████████████████████████████████████████████████████████████████████████████▌ | 486/495 [00:26<00:00, 15.23it/s]
# Processing 400x OSCC Histopathological Images:  99%|███████████████████████████████████████████████████████████████████████████████▊ | 488/495 [00:27<00:00, 13.13it/s]
# Processing 400x OSCC Histopathological Images:  99%|████████████████████████████████████████████████████████████████████████████████▏| 490/495 [00:27<00:00, 13.39it/s]
# Processing 400x OSCC Histopathological Images:  99%|████████████████████████████████████████████████████████████████████████████████▌| 492/495 [00:27<00:00, 14.25it/s]
# Processing 400x OSCC Histopathological Images: 100%|█████████████████████████████████████████████████████████████████████████████████| 495/495 [00:27<00:00, 16.36it/s]
# Processing classes: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:39<00:00, 19.50s/it]

# %%
#Stain Normalization:

# Optical Density (OD) normalization constants
Io = 240        # Light intensity used in image formation
alpha = 1       # Percentile threshold to exclude extreme angles in stain vectors
beta = 0.15     # Threshold for OD filtering


# Reference H&E stain matrix (predefined based on a reference image)
HERef = tf.constant([[0.5626, 0.2159],
                     [0.7201, 0.8012],
                     [0.4062, 0.5581]], dtype=tf.float32) 

maxCRef = np.array([1.9705, 1.0308])   # Reference stain concentration percentiles


def process_single_image(img):
    h, w, _ = img.shape   # Get image dimensions (height, width, channels)
    img_flat = img.reshape((-1, 3))  # Flatten image to 2D array of pixels (N, 3)

    OD = -tf.math.log((tf.cast(img_flat, tf.float32) + 1) / Io) # Convert RGB to optical density (OD)

    mask = tf.reduce_all(OD >= beta, axis=1) # Mask to filter out low OD values (background or noise)
    
    ODhat = tf.boolean_mask(OD, mask) # Apply mask to retain only meaningful stain regions

    # Perform PCA on ODhat to find principal stain directions
    eigvals, eigvecs = np.linalg.eigh(np.cov(ODhat.numpy().T))
    eigvecs_tf = tf.convert_to_tensor(eigvecs, dtype=tf.float32)

    
    That = tf.matmul(ODhat, eigvecs_tf[:, 1:3]) # Project ODhat onto 2 principal components

    
    phi = tf.math.atan2(That[:, 1], That[:, 0]).numpy() # Compute angles (phi) of projected data for stain vector estimation

    # Compute angle percentiles to exclude outliers
    minPhi = np.percentile(phi, alpha)
    maxPhi = np.percentile(phi, 100 - alpha)

    # Compute stain vectors based on min and max angle projections
    vMin = eigvecs_tf[:, 1:3] @ tf.constant([[np.cos(minPhi)], [np.sin(minPhi)]], dtype=tf.float32)
    vMax = eigvecs_tf[:, 1:3] @ tf.constant([[np.cos(maxPhi)], [np.sin(maxPhi)]], dtype=tf.float32)

    # Order stain vectors: Hematoxylin first, Eosin second
    HE = tf.concat([vMin, vMax], axis=1) if vMin[0] > vMax[0] else tf.concat([vMax, vMin], axis=1)
    
    # Solve OD = HE * C using least squares to get stain concentrations
    Y = tf.transpose(OD)
    C = tf.linalg.lstsq(HE, Y, l2_regularizer=1e-10)

    
    C_np = C.numpy() # Convert concentrations to numpy for further processing

    # Normalize stain concentrations using 99th percentile
    maxC = np.array([np.percentile(C_np[0, :], 99), np.percentile(C_np[1, :], 99)])
    tmp = maxC / maxCRef
    C2 = C_np / tmp[:, np.newaxis]
    C2_tf = tf.convert_to_tensor(C2, dtype=tf.float32)

    # Reconstruct normalized image using reference stain matrix
    Inorm = Io * tf.exp(-tf.matmul(HERef, C2_tf))
    Inorm = tf.clip_by_value(Inorm, 0, 255)

    # Reshape and convert back to image format (uint8)
    Inorm_img = tf.reshape(tf.transpose(Inorm), (h, w, 3)).numpy().astype(np.uint8)
    
    return Inorm_img


def process_directory(input_dir, output_dir):
    class_folders = [d for d in os.listdir(input_dir) if os.path.isdir(os.path.join(input_dir, d))]
    for class_name in class_folders:
        input_class_path = os.path.join(input_dir, class_name)
        output_class_path = os.path.join(output_dir, class_name)
        os.makedirs(output_class_path, exist_ok=True)

        for file in tqdm(os.listdir(input_class_path), desc=f"Processing {class_name}"):
            if file.lower().endswith(('.jpg')):
                in_path = os.path.join(input_class_path, file)
                try:
                    img = Image.open(in_path).convert("RGB") # Load image and convert to RGB numpy array
                    img_np = np.array(img)
                    
                    norm_img = process_single_image(img_np)   # Perform stain normalization

                    # Save normalized image to output directory
                    out_path = os.path.join(output_class_path, os.path.splitext(file)[0] + "_normalized.png")
                    Image.fromarray(norm_img).save(out_path)
                    
                except Exception as e:
                    print(f"❌ Failed to process {in_path}: {e}")


process_directory(preprocessed_path2, preprocessed_path3)
# Out:
# Processing 400x Normal Oral Cavity Histopathological Images: 100%|███████████████████████████████████████████████████████████████████| 201/201 [00:12<00:00, 15.86it/s]
# Processing 400x OSCC Histopathological Images: 100%|█████████████████████████████████████████████████████████████████████████████████| 495/495 [00:31<00:00, 15.81it/s]

# %%
#CLAHE

# Create output directory structure
class_dirs = [d for d in os.listdir(preprocessed_path3) if os.path.isdir(os.path.join(preprocessed_path3, d))]
for class_dir in class_dirs:
    os.makedirs(os.path.join(preprocessed_path4, class_dir), exist_ok=True)

# Apply CLAHE using OpenCV
def apply_clahe_to_image(image_np):
    lab = cv2.cvtColor(image_np, cv2.COLOR_RGB2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.5, tileGridSize=(16, 16))
    l_clahe = clahe.apply(l)
    lab_clahe = cv2.merge((l_clahe, a, b))
    img_clahe = cv2.cvtColor(lab_clahe, cv2.COLOR_LAB2RGB)
    return img_clahe

# Process all images
for class_dir in class_dirs:
    input_class_path = os.path.join(preprocessed_path3, class_dir)
    output_class_path = os.path.join(preprocessed_path4, class_dir)

    image_paths = glob(os.path.join(input_class_path, "*.png"))

    for image_path in tqdm(image_paths, desc=f"Processing {class_dir}"):
 
        image = tf.io.read_file(image_path)
        image = tf.image.decode_png(image, channels=3) 
        image = tf.image.convert_image_dtype(image, tf.uint8)

        image_np = image.numpy()
        
        # Apply CLAHE
        clahe_image = apply_clahe_to_image(image_np)

        # Save output
        image_name = os.path.basename(image_path)
        output_path = os.path.join(output_class_path, image_name)
        cv2.imwrite(output_path, cv2.cvtColor(clahe_image, cv2.COLOR_RGB2BGR))
# Out:
# Processing 400x Normal Oral Cavity Histopathological Images: 100%|███████████████████████████████████████████████████████████████████| 201/201 [00:07<00:00, 27.80it/s]
# Processing 400x OSCC Histopathological Images: 100%|█████████████████████████████████████████████████████████████████████████████████| 495/495 [00:15<00:00, 32.18it/s]

# %%
#DATA AUGMENTATION:

#rotation, shifting, shearing, zoooming, flipping, brightness, contrasting, noise, blurring.

# Files
INPUT_DIR = preprocessed_path4
OUTPUT_DIR = "D:/final year project/augmentation_after_pre/augmented_dataset/"
os.makedirs(OUTPUT_DIR, exist_ok= True)

# Output classes:
os.makedirs(os.path.join(OUTPUT_DIR, "400x Normal Oral Cavity Histopathological Images"), exist_ok=True)
os.makedirs(os.path.join(OUTPUT_DIR, "400x OSCC Histopathological Images"), exist_ok=True)

#Configurations:
TARGET_COUNT = 5000
BATCH_SIZE = 1


# PipeLine:
datagen = ImageDataGenerator(
    rotation_range=12,
    width_shift_range=0.07,
    height_shift_range=0.07,
    shear_range=0.05,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='reflect',
    brightness_range=[0.8, 1], 
)

# Add Noise, Blur, Random Contrast
def add_more(image):
    # Normalizing and Gaussian noise 
    image = image.astype(np.float32) / 255.0 
    noise = np.random.normal(loc=0, scale=0.01, size=image.shape).astype(np.float32)
    noisy_image = image + noise
    np.clip(noisy_image, 0.0, 1.0, out=noisy_image)

    # Convert to uint8
    image_uint8 = (noisy_image * 255).astype(np.uint8)

    # Gaussian Blur
    kernel_size = np.random.choice([3, 5])
    blurred_image = cv2.GaussianBlur(image_uint8, (kernel_size, kernel_size), 
                                   sigmaX=np.random.uniform(0.3, 0.5))

    # Random Contrast
    alpha = np.random.uniform(0.7, 1.3)  
    contrast_img = cv2.convertScaleAbs(blurred_image, alpha=alpha, beta=np.random.uniform(-10, 10))

    return contrast_img

# Augment Each Class 
def augment_class(class_name, target_count):
    input_path = os.path.join(INPUT_DIR, class_name)
    output_path = os.path.join(OUTPUT_DIR, class_name)

    os.makedirs(output_path, exist_ok=True)
    
    original_images = [os.path.join(input_path, f) for f in os.listdir(input_path) 
                     if f.endswith(('.jpg', '.png'))]
    existing_augmented = [f for f in os.listdir(output_path) if f.endswith(('.jpg', '.png'))]

    current_count = len(existing_augmented)
    remaining = target_count - current_count

    if remaining <= 0:
        print(f"[INFO] {class_name}: Already has {current_count} images.")
        return

    print(f"\n[INFO] Augmenting '{class_name}' from {current_count} to {target_count} images")

    img_index = 0
    pbar = tqdm(total=remaining, desc=f"Augmenting {class_name}")

    while remaining > 0:
        img_path = original_images[img_index % len(original_images)]

        try:
            with Image.open(img_path).convert('RGB') as img:
                img_array = np.expand_dims(np.array(img), axis=0).astype(np.float32)
                
                # Generate multiple augmentations per image
                num_augmentations = min(remaining, np.random.randint(4, 7))  #4 to 7 images/image
                
                for i, batch in enumerate(datagen.flow(img_array, batch_size=1)):
                    if i >= num_augmentations:
                        break
                        
                    augmented_img = batch[0]
                    augmented = add_more(augmented_img)
                    augmented = np.uint8(augmented)

                    filename = f"aug_{os.path.splitext(os.path.basename(img_path))[0]}_{i}_{int(time.time())}.jpg"
                    save_path = os.path.join(output_path, filename)
                    Image.fromarray(augmented).save(save_path)

                    remaining -= 1
                    pbar.update(1)
                    
                    if remaining <= 0:
                        break

        except Exception as e:
            print(f"[ERROR] Failed on {img_path}: {str(e)}")

        img_index += 1

    pbar.close()
    print(f"[DONE] {class_name}: Total images = {len(os.listdir(output_path))}")

# Run Augmentation
augment_class("400x Normal Oral Cavity Histopathological Images", TARGET_COUNT)
augment_class("400x OSCC Histopathological Images", TARGET_COUNT)

# Statistics:
print(f"\n[SUCCESS] Augmentation complete. Output saved to: {OUTPUT_DIR}")
print(f"Final counts:")
print(f"- Normal: {len(os.listdir(os.path.join(OUTPUT_DIR, '400x Normal Oral Cavity Histopathological Images')))} images")
print(f"- OSCC: {len(os.listdir(os.path.join(OUTPUT_DIR, '400x OSCC Histopathological Images')))} images")
# Out:
# [INFO] Augmenting '400x Normal Oral Cavity Histopathological Images' from 0 to 5000 images
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                            | 0/5000 [00:00<?, ?it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                    | 1/5000 [00:00<10:08,  8.21it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                    | 2/5000 [00:00<11:35,  7.18it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                    | 3/5000 [00:00<10:16,  8.11it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                    | 4/5000 [00:00<09:31,  8.74it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                    | 5/5000 [00:00<10:07,  8.23it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                    | 6/5000 [00:00<11:59,  6.94it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                    | 8/5000 [00:00<09:28,  8.78it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                   | 10/5000 [00:01<09:56,  8.37it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                   | 11/5000 [00:01<10:19,  8.05it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                   | 12/5000 [00:01<10:47,  7.71it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                   | 13/5000 [00:01<12:07,  6.86it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                   | 14/5000 [00:01<11:41,  7.11it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                   | 15/5000 [00:02<16:31,  5.03it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                   | 16/5000 [00:02<14:29,  5.73it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                   | 18/5000 [00:02<10:39,  7.80it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                   | 20/5000 [00:02<10:11,  8.14it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                   | 22/5000 [00:02<08:43,  9.51it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   0%|                   | 24/5000 [00:02<08:05, 10.24it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|                   | 26/5000 [00:03<09:42,  8.53it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|                   | 28/5000 [00:03<08:40,  9.56it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|                   | 30/5000 [00:03<08:52,  9.34it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|                   | 32/5000 [00:04<11:12,  7.39it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 33/5000 [00:04<11:42,  7.07it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 34/5000 [00:04<11:59,  6.90it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 35/5000 [00:04<11:24,  7.25it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 36/5000 [00:04<10:40,  7.74it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 37/5000 [00:04<10:51,  7.62it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 38/5000 [00:04<11:48,  7.00it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 39/5000 [00:05<10:50,  7.62it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 41/5000 [00:05<09:05,  9.09it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 42/5000 [00:05<12:13,  6.76it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 43/5000 [00:05<11:57,  6.91it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 45/5000 [00:05<10:08,  8.14it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 46/5000 [00:06<12:59,  6.36it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 47/5000 [00:06<12:27,  6.63it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 48/5000 [00:06<14:22,  5.74it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 49/5000 [00:06<15:00,  5.50it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 50/5000 [00:06<15:36,  5.29it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 51/5000 [00:06<14:44,  5.59it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 52/5000 [00:07<13:14,  6.23it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 53/5000 [00:07<13:13,  6.23it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 55/5000 [00:07<10:30,  7.85it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 56/5000 [00:07<10:54,  7.55it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 57/5000 [00:07<11:03,  7.45it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 58/5000 [00:07<11:06,  7.41it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 59/5000 [00:08<12:51,  6.40it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 60/5000 [00:08<16:11,  5.09it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 61/5000 [00:08<13:55,  5.91it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 62/5000 [00:08<14:37,  5.63it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 63/5000 [00:09<19:19,  4.26it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 64/5000 [00:09<32:52,  2.50it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▏                  | 65/5000 [00:10<29:35,  2.78it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▎                  | 66/5000 [00:10<25:25,  3.23it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▎                  | 67/5000 [00:10<21:53,  3.76it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▎                  | 68/5000 [00:10<18:09,  4.53it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▎                  | 69/5000 [00:10<15:37,  5.26it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▎                  | 70/5000 [00:10<15:36,  5.26it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▎                  | 71/5000 [00:11<13:57,  5.89it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▎                  | 72/5000 [00:11<15:27,  5.31it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▎                  | 73/5000 [00:11<14:41,  5.59it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   1%|▎                  | 74/5000 [00:11<15:04,  5.44it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 75/5000 [00:11<13:54,  5.90it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 76/5000 [00:11<14:45,  5.56it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 78/5000 [00:12<12:23,  6.62it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 79/5000 [00:12<12:37,  6.49it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 80/5000 [00:12<11:33,  7.10it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 81/5000 [00:12<11:43,  7.00it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 82/5000 [00:12<11:18,  7.25it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 83/5000 [00:12<11:57,  6.85it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 85/5000 [00:13<09:58,  8.22it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 87/5000 [00:13<12:30,  6.54it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 88/5000 [00:13<15:50,  5.17it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 89/5000 [00:14<16:50,  4.86it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 90/5000 [00:14<15:36,  5.24it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 91/5000 [00:14<13:55,  5.87it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 92/5000 [00:14<13:31,  6.05it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 93/5000 [00:14<14:59,  5.46it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 94/5000 [00:14<13:45,  5.94it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 95/5000 [00:14<12:40,  6.45it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 97/5000 [00:15<10:29,  7.79it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                  | 98/5000 [00:15<10:49,  7.55it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                  | 99/5000 [00:15<10:10,  8.03it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                 | 100/5000 [00:15<10:55,  7.48it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                 | 101/5000 [00:15<11:37,  7.02it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                 | 102/5000 [00:15<11:46,  6.93it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                 | 103/5000 [00:15<11:22,  7.18it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▎                 | 104/5000 [00:16<13:02,  6.26it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 105/5000 [00:16<12:55,  6.31it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 106/5000 [00:16<12:22,  6.59it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 107/5000 [00:16<12:09,  6.71it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 109/5000 [00:16<10:57,  7.44it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 110/5000 [00:16<10:24,  7.83it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 111/5000 [00:17<10:20,  7.88it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 112/5000 [00:17<10:15,  7.94it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 113/5000 [00:17<10:03,  8.10it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 114/5000 [00:17<11:15,  7.24it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 115/5000 [00:17<10:22,  7.85it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 116/5000 [00:17<09:55,  8.19it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 117/5000 [00:17<09:25,  8.64it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 118/5000 [00:17<09:11,  8.86it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 119/5000 [00:18<08:53,  9.15it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 120/5000 [00:18<11:46,  6.91it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 121/5000 [00:18<11:10,  7.28it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 123/5000 [00:18<08:49,  9.21it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   2%|▍                 | 124/5000 [00:18<09:28,  8.57it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▍                 | 126/5000 [00:18<08:11,  9.92it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▍                 | 128/5000 [00:18<07:23, 10.98it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▍                 | 130/5000 [00:19<07:32, 10.77it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▍                 | 132/5000 [00:19<07:19, 11.08it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▍                 | 134/5000 [00:19<06:52, 11.78it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▍                 | 136/5000 [00:19<07:34, 10.70it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▍                 | 138/5000 [00:19<07:54, 10.24it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 140/5000 [00:20<08:18,  9.75it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 141/5000 [00:20<08:23,  9.64it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 143/5000 [00:20<08:18,  9.75it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 145/5000 [00:20<07:50, 10.33it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 147/5000 [00:20<08:33,  9.44it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 149/5000 [00:21<07:55, 10.19it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 151/5000 [00:21<07:18, 11.06it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 153/5000 [00:21<07:28, 10.80it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 155/5000 [00:21<06:59, 11.54it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 157/5000 [00:21<06:41, 12.07it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 159/5000 [00:21<07:22, 10.93it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 161/5000 [00:22<06:53, 11.70it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 163/5000 [00:22<07:07, 11.30it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 165/5000 [00:22<06:55, 11.63it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 167/5000 [00:22<06:31, 12.34it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 169/5000 [00:22<06:55, 11.63it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 171/5000 [00:22<06:33, 12.28it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   3%|▌                 | 173/5000 [00:23<06:27, 12.45it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 175/5000 [00:23<09:21,  8.59it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 177/5000 [00:23<08:40,  9.27it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 179/5000 [00:23<09:12,  8.73it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 180/5000 [00:23<09:24,  8.54it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 182/5000 [00:24<08:12,  9.79it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 184/5000 [00:24<07:51, 10.22it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 186/5000 [00:24<07:59, 10.05it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 188/5000 [00:24<07:33, 10.61it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 190/5000 [00:24<06:57, 11.53it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 192/5000 [00:25<07:24, 10.82it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 194/5000 [00:25<07:10, 11.15it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 196/5000 [00:25<09:00,  8.90it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 198/5000 [00:25<08:18,  9.63it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 200/5000 [00:25<08:53,  9.00it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 201/5000 [00:26<09:38,  8.29it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 202/5000 [00:26<09:55,  8.06it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 203/5000 [00:26<13:12,  6.05it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 204/5000 [00:26<12:45,  6.26it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 205/5000 [00:26<12:29,  6.39it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 206/5000 [00:26<11:52,  6.73it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▋                 | 208/5000 [00:27<09:45,  8.18it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▊                 | 209/5000 [00:27<09:44,  8.19it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▊                 | 210/5000 [00:27<09:54,  8.06it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▊                 | 211/5000 [00:27<10:23,  7.68it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▊                 | 213/5000 [00:27<08:42,  9.16it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▊                 | 214/5000 [00:27<09:22,  8.51it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▊                 | 215/5000 [00:27<09:22,  8.50it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▊                 | 216/5000 [00:28<09:10,  8.69it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▊                 | 217/5000 [00:28<14:56,  5.34it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▊                 | 218/5000 [00:28<16:34,  4.81it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▊                 | 219/5000 [00:28<16:03,  4.96it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▊                 | 220/5000 [00:29<13:50,  5.76it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▊                 | 222/5000 [00:29<13:50,  5.75it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▊                 | 223/5000 [00:29<21:43,  3.66it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▊                 | 224/5000 [00:30<19:20,  4.12it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   4%|▊                 | 225/5000 [00:30<17:22,  4.58it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 226/5000 [00:30<18:20,  4.34it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 227/5000 [00:30<17:51,  4.46it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 228/5000 [00:30<15:16,  5.21it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 229/5000 [00:30<13:31,  5.88it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 230/5000 [00:31<16:00,  4.97it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 231/5000 [00:31<18:07,  4.39it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 232/5000 [00:31<21:40,  3.67it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 233/5000 [00:32<22:17,  3.56it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 234/5000 [00:32<19:12,  4.13it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 235/5000 [00:32<24:21,  3.26it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 236/5000 [00:33<25:19,  3.14it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 237/5000 [00:33<22:59,  3.45it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 238/5000 [00:33<20:05,  3.95it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 239/5000 [00:33<21:07,  3.76it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 240/5000 [00:33<18:35,  4.27it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 241/5000 [00:34<19:08,  4.14it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 242/5000 [00:34<16:03,  4.94it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▊                 | 243/5000 [00:34<15:24,  5.15it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 244/5000 [00:34<19:41,  4.02it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 245/5000 [00:35<17:04,  4.64it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 246/5000 [00:35<15:34,  5.09it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 247/5000 [00:35<16:37,  4.76it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 248/5000 [00:35<14:26,  5.48it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 249/5000 [00:35<12:47,  6.19it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 250/5000 [00:35<11:51,  6.68it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 251/5000 [00:35<11:18,  7.00it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 252/5000 [00:36<12:28,  6.34it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 253/5000 [00:36<12:33,  6.30it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 255/5000 [00:36<09:38,  8.20it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 256/5000 [00:36<10:41,  7.40it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 257/5000 [00:36<10:15,  7.70it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 259/5000 [00:36<08:43,  9.05it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 260/5000 [00:37<08:37,  9.16it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 261/5000 [00:37<10:59,  7.18it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 262/5000 [00:37<10:27,  7.56it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 263/5000 [00:37<10:09,  7.78it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 264/5000 [00:37<10:17,  7.67it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 265/5000 [00:37<11:34,  6.82it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 266/5000 [00:37<11:03,  7.14it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 267/5000 [00:38<10:43,  7.36it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 269/5000 [00:38<08:40,  9.10it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 270/5000 [00:38<08:43,  9.03it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 271/5000 [00:38<11:31,  6.84it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 272/5000 [00:38<10:35,  7.44it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 273/5000 [00:38<10:46,  7.31it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   5%|▉                 | 274/5000 [00:38<10:05,  7.81it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|▉                 | 275/5000 [00:39<10:30,  7.49it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|▉                 | 276/5000 [00:39<10:02,  7.84it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 278/5000 [00:39<08:38,  9.11it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 279/5000 [00:39<10:28,  7.52it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 280/5000 [00:39<10:14,  7.68it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 282/5000 [00:39<08:29,  9.27it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 283/5000 [00:40<10:10,  7.73it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 285/5000 [00:40<08:28,  9.27it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 286/5000 [00:40<08:36,  9.12it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 287/5000 [00:40<09:43,  8.07it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 288/5000 [00:40<09:46,  8.04it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 289/5000 [00:40<09:40,  8.11it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 290/5000 [00:40<09:41,  8.10it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 291/5000 [00:40<09:22,  8.38it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 292/5000 [00:41<10:30,  7.47it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 293/5000 [00:41<09:43,  8.06it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 295/5000 [00:41<08:05,  9.70it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 296/5000 [00:41<09:43,  8.06it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 297/5000 [00:41<11:26,  6.85it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 298/5000 [00:41<11:48,  6.63it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 299/5000 [00:42<11:16,  6.95it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 300/5000 [00:42<10:19,  7.59it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 301/5000 [00:42<09:40,  8.10it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 302/5000 [00:42<11:53,  6.59it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 303/5000 [00:42<10:46,  7.26it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 304/5000 [00:42<09:59,  7.83it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 306/5000 [00:42<08:19,  9.40it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 307/5000 [00:42<08:38,  9.05it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 308/5000 [00:43<08:30,  9.19it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 309/5000 [00:43<08:26,  9.26it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█                 | 311/5000 [00:43<08:39,  9.02it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█▏                | 313/5000 [00:43<07:52,  9.93it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█▏                | 315/5000 [00:43<07:59,  9.77it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█▏                | 317/5000 [00:43<07:03, 11.06it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█▏                | 319/5000 [00:44<06:36, 11.79it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█▏                | 321/5000 [00:44<10:08,  7.70it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█▏                | 322/5000 [00:44<09:55,  7.86it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   6%|█▏                | 324/5000 [00:44<08:48,  8.85it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▏                | 326/5000 [00:45<08:50,  8.81it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▏                | 327/5000 [00:45<09:26,  8.25it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▏                | 329/5000 [00:45<08:30,  9.15it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▏                | 331/5000 [00:45<08:18,  9.36it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▏                | 333/5000 [00:45<07:43, 10.07it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▏                | 335/5000 [00:45<07:20, 10.60it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▏                | 337/5000 [00:46<07:42, 10.07it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▏                | 339/5000 [00:46<08:03,  9.63it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▏                | 341/5000 [00:46<08:11,  9.47it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▏                | 342/5000 [00:46<08:29,  9.14it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▏                | 343/5000 [00:46<08:28,  9.16it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▏                | 344/5000 [00:46<08:31,  9.10it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▏                | 346/5000 [00:47<07:31, 10.31it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▎                | 348/5000 [00:47<07:59,  9.70it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▎                | 350/5000 [00:47<07:29, 10.35it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▎                | 352/5000 [00:47<06:50, 11.32it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▎                | 354/5000 [00:47<08:01,  9.66it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▎                | 356/5000 [00:48<07:18, 10.60it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▎                | 358/5000 [00:48<07:22, 10.50it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▎                | 360/5000 [00:48<06:44, 11.47it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▎                | 362/5000 [00:48<06:21, 12.17it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▎                | 364/5000 [00:48<07:08, 10.81it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▎                | 366/5000 [00:48<06:43, 11.48it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▎                | 368/5000 [00:49<06:23, 12.07it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▎                | 370/5000 [00:49<06:56, 11.13it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▎                | 372/5000 [00:49<06:27, 11.94it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   7%|█▎                | 374/5000 [00:49<06:02, 12.78it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▎                | 376/5000 [00:49<06:46, 11.36it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▎                | 378/5000 [00:49<06:50, 11.25it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▎                | 380/5000 [00:50<06:16, 12.26it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 382/5000 [00:50<07:19, 10.50it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 384/5000 [00:50<07:06, 10.82it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 386/5000 [00:50<06:47, 11.33it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 388/5000 [00:50<07:43,  9.96it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 390/5000 [00:51<07:22, 10.41it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 392/5000 [00:51<07:45,  9.90it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 394/5000 [00:51<07:10, 10.70it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 396/5000 [00:51<07:00, 10.94it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 398/5000 [00:51<07:31, 10.19it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 400/5000 [00:52<07:40,  9.98it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 402/5000 [00:52<07:59,  9.58it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 404/5000 [00:52<07:12, 10.62it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 406/5000 [00:52<08:08,  9.41it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 408/5000 [00:52<08:15,  9.27it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 409/5000 [00:53<08:38,  8.86it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 410/5000 [00:53<10:42,  7.15it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 411/5000 [00:53<10:57,  6.98it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 412/5000 [00:53<10:37,  7.19it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 414/5000 [00:53<08:43,  8.76it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▍                | 415/5000 [00:53<10:28,  7.30it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▌                | 417/5000 [00:54<08:44,  8.74it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▌                | 419/5000 [00:54<09:08,  8.35it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▌                | 421/5000 [00:54<08:04,  9.44it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▌                | 423/5000 [00:54<07:24, 10.29it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   8%|█▌                | 425/5000 [00:54<08:11,  9.30it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▌                | 427/5000 [00:55<07:12, 10.58it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▌                | 429/5000 [00:55<06:29, 11.74it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▌                | 431/5000 [00:55<07:31, 10.11it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▌                | 433/5000 [00:55<07:22, 10.32it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▌                | 435/5000 [00:55<06:37, 11.47it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▌                | 437/5000 [00:56<07:24, 10.26it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▌                | 439/5000 [00:56<07:16, 10.46it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▌                | 441/5000 [00:56<07:29, 10.14it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▌                | 443/5000 [00:56<06:57, 10.93it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▌                | 445/5000 [00:56<07:13, 10.51it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▌                | 447/5000 [00:57<09:11,  8.26it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▌                | 448/5000 [00:57<09:00,  8.42it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▌                | 449/5000 [00:57<09:50,  7.71it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▌                | 450/5000 [00:57<10:13,  7.41it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▌                | 451/5000 [00:57<09:51,  7.69it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 452/5000 [00:57<09:36,  7.89it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 453/5000 [00:58<14:40,  5.16it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 454/5000 [00:58<14:26,  5.24it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 455/5000 [00:58<14:22,  5.27it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 456/5000 [00:58<13:00,  5.82it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 458/5000 [00:58<09:43,  7.78it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 459/5000 [00:59<20:35,  3.68it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 460/5000 [00:59<18:16,  4.14it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 462/5000 [00:59<13:20,  5.67it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 463/5000 [00:59<12:24,  6.10it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 464/5000 [01:00<15:44,  4.80it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 465/5000 [01:00<14:09,  5.34it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 466/5000 [01:00<12:59,  5.81it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 467/5000 [01:00<11:51,  6.38it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 469/5000 [01:00<09:31,  7.92it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 470/5000 [01:01<10:20,  7.30it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 471/5000 [01:01<09:45,  7.73it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:   9%|█▋                | 473/5000 [01:01<08:55,  8.46it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▋                | 475/5000 [01:01<08:10,  9.23it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▋                | 476/5000 [01:01<12:13,  6.17it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▋                | 477/5000 [01:02<11:22,  6.63it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▋                | 478/5000 [01:02<10:29,  7.18it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▋                | 480/5000 [01:02<09:13,  8.16it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▋                | 481/5000 [01:02<09:34,  7.86it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▋                | 482/5000 [01:02<16:23,  4.60it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▋                | 483/5000 [01:03<14:05,  5.34it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▋                | 485/5000 [01:03<10:45,  6.99it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▋                | 486/5000 [01:03<15:57,  4.72it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 487/5000 [01:03<14:22,  5.23it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 488/5000 [01:03<13:07,  5.73it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 489/5000 [01:04<12:15,  6.13it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 491/5000 [01:04<14:35,  5.15it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 493/5000 [01:04<11:05,  6.77it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 495/5000 [01:04<09:27,  7.94it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 496/5000 [01:04<09:34,  7.84it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 497/5000 [01:05<14:43,  5.09it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 498/5000 [01:05<13:10,  5.69it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 500/5000 [01:05<10:46,  6.96it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 502/5000 [01:05<08:47,  8.53it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 504/5000 [01:06<08:24,  8.91it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 506/5000 [01:06<07:28, 10.01it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 508/5000 [01:06<08:45,  8.55it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 510/5000 [01:06<07:41,  9.72it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 512/5000 [01:06<08:09,  9.17it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 514/5000 [01:07<07:16, 10.28it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 516/5000 [01:07<06:32, 11.43it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 518/5000 [01:07<07:05, 10.53it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▊                | 520/5000 [01:07<06:31, 11.45it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▉                | 522/5000 [01:07<07:59,  9.35it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  10%|█▉                | 524/5000 [01:08<07:25, 10.06it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|█▉                | 526/5000 [01:08<08:17,  8.99it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|█▉                | 528/5000 [01:08<07:17, 10.22it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|█▉                | 530/5000 [01:08<08:46,  8.49it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|█▉                | 532/5000 [01:08<07:26, 10.00it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|█▉                | 534/5000 [01:09<06:50, 10.87it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|█▉                | 536/5000 [01:09<08:34,  8.68it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|█▉                | 538/5000 [01:09<08:26,  8.81it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|█▉                | 540/5000 [01:09<07:49,  9.50it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|█▉                | 542/5000 [01:09<07:34,  9.81it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|█▉                | 544/5000 [01:10<06:36, 11.23it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|█▉                | 546/5000 [01:10<06:53, 10.76it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|█▉                | 548/5000 [01:10<06:23, 11.62it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|█▉                | 550/5000 [01:10<06:04, 12.22it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|█▉                | 552/5000 [01:10<08:31,  8.70it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|█▉                | 554/5000 [01:11<07:52,  9.41it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|██                | 556/5000 [01:11<07:11, 10.31it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|██                | 558/5000 [01:11<07:48,  9.49it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|██                | 560/5000 [01:11<07:01, 10.55it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|██                | 562/5000 [01:11<06:11, 11.96it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|██                | 564/5000 [01:11<06:25, 11.50it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|██                | 566/5000 [01:12<05:49, 12.70it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|██                | 568/5000 [01:12<05:35, 13.20it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|██                | 570/5000 [01:12<07:08, 10.33it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|██                | 572/5000 [01:12<06:33, 11.24it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  11%|██                | 574/5000 [01:12<08:00,  9.21it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  12%|██                | 576/5000 [01:13<07:21, 10.03it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  12%|██                | 578/5000 [01:13<07:01, 10.48it/s]
# Augmenting 400x Normal Oral Cavity Histopathological Images:  12%|██                | 580/5000 [01:13<07:12, 10.23it/s]
# ...
# Augmenting 400x OSCC Histopathological Images:  18%|█████▊                          | 910/5000 [01:12<04:08, 16.47it/s]
# Augmenting 400x OSCC Histopathological Images:  18%|█████▊                          | 913/5000 [01:13<03:53, 17.48it/s]
# Augmenting 400x OSCC Histopathological Images:  18%|█████▊                          | 915/5000 [01:13<04:23, 15.50it/s]
# Augmenting 400x OSCC Histopathological Images:  18%|█████▉                          | 918/5000 [01:13<03:57, 17.18it/s]
# Augmenting 400x OSCC Histopathological Images:  18%|█████▉                          | 920/5000 [01:13<04:58, 13.68it/s]
# Augmenting 400x OSCC Histopathological Images:  18%|█████▉                          | 923/5000 [01:13<04:50, 14.04it/s]
# Augmenting 400x OSCC Histopathological Images:  18%|█████▉                          | 925/5000 [01:14<05:19, 12.77it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|█████▉                          | 927/5000 [01:14<04:56, 13.71it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|█████▉                          | 929/5000 [01:14<04:53, 13.87it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|█████▉                          | 932/5000 [01:14<04:17, 15.83it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|█████▉                          | 934/5000 [01:14<04:38, 14.60it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|█████▉                          | 937/5000 [01:14<04:28, 15.14it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|██████                          | 940/5000 [01:15<04:11, 16.13it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|██████                          | 942/5000 [01:15<04:13, 15.99it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|██████                          | 944/5000 [01:15<05:12, 12.99it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|██████                          | 946/5000 [01:15<04:46, 14.14it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|██████                          | 948/5000 [01:15<05:19, 12.68it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|██████                          | 950/5000 [01:15<05:31, 12.23it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|██████                          | 952/5000 [01:16<05:24, 12.48it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|██████                          | 954/5000 [01:16<06:03, 11.12it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|██████                          | 956/5000 [01:16<05:46, 11.69it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|██████▏                         | 958/5000 [01:16<05:17, 12.72it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|██████▏                         | 960/5000 [01:16<06:29, 10.37it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|██████▏                         | 962/5000 [01:16<06:04, 11.06it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|██████▏                         | 964/5000 [01:17<06:12, 10.83it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|██████▏                         | 967/5000 [01:17<05:03, 13.31it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|██████▏                         | 969/5000 [01:17<05:05, 13.20it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|██████▏                         | 972/5000 [01:17<04:23, 15.30it/s]
# Augmenting 400x OSCC Histopathological Images:  19%|██████▏                         | 974/5000 [01:17<04:31, 14.84it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                         | 977/5000 [01:17<03:59, 16.77it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                         | 979/5000 [01:18<04:23, 15.26it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                         | 981/5000 [01:18<04:10, 16.03it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                         | 983/5000 [01:18<03:57, 16.93it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                         | 985/5000 [01:18<04:40, 14.29it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                         | 988/5000 [01:18<03:57, 16.91it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                         | 990/5000 [01:18<04:19, 15.43it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                         | 992/5000 [01:18<04:08, 16.10it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                         | 994/5000 [01:19<04:55, 13.57it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                         | 996/5000 [01:19<04:28, 14.91it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▍                         | 999/5000 [01:19<04:25, 15.07it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▏                        | 1002/5000 [01:19<03:52, 17.22it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▏                        | 1004/5000 [01:19<03:49, 17.45it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▏                        | 1006/5000 [01:19<04:35, 14.50it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▏                        | 1008/5000 [01:19<04:29, 14.79it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                        | 1010/5000 [01:20<04:12, 15.83it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                        | 1012/5000 [01:20<04:26, 14.99it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                        | 1015/5000 [01:20<03:57, 16.76it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                        | 1017/5000 [01:20<04:43, 14.03it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                        | 1019/5000 [01:20<04:39, 14.25it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                        | 1021/5000 [01:20<04:37, 14.36it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                        | 1023/5000 [01:20<05:08, 12.89it/s]
# Augmenting 400x OSCC Histopathological Images:  20%|██████▎                        | 1025/5000 [01:21<04:56, 13.43it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▎                        | 1027/5000 [01:21<04:57, 13.35it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▍                        | 1029/5000 [01:21<05:35, 11.82it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▍                        | 1031/5000 [01:21<05:10, 12.77it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▍                        | 1034/5000 [01:21<05:04, 13.04it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▍                        | 1037/5000 [01:21<04:22, 15.10it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▍                        | 1040/5000 [01:22<04:26, 14.85it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▍                        | 1043/5000 [01:22<04:00, 16.47it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▍                        | 1045/5000 [01:22<05:02, 13.06it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▍                        | 1047/5000 [01:22<04:50, 13.59it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▌                        | 1049/5000 [01:22<05:21, 12.27it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▌                        | 1051/5000 [01:23<05:02, 13.07it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▌                        | 1053/5000 [01:23<04:48, 13.67it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▌                        | 1055/5000 [01:23<05:49, 11.30it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▌                        | 1057/5000 [01:23<05:08, 12.79it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▌                        | 1059/5000 [01:23<05:23, 12.19it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▌                        | 1061/5000 [01:23<05:43, 11.46it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▌                        | 1063/5000 [01:24<05:50, 11.23it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▌                        | 1065/5000 [01:24<05:16, 12.43it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▌                        | 1067/5000 [01:24<05:24, 12.12it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▋                        | 1069/5000 [01:24<04:55, 13.29it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▋                        | 1071/5000 [01:24<05:01, 13.02it/s]
# Augmenting 400x OSCC Histopathological Images:  21%|██████▋                        | 1074/5000 [01:24<04:13, 15.49it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▋                        | 1076/5000 [01:24<04:41, 13.96it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▋                        | 1079/5000 [01:25<04:01, 16.26it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▋                        | 1081/5000 [01:25<04:13, 15.48it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▋                        | 1084/5000 [01:25<03:45, 17.40it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▋                        | 1086/5000 [01:25<04:29, 14.50it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▋                        | 1088/5000 [01:25<04:11, 15.58it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▊                        | 1091/5000 [01:25<04:26, 14.66it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▊                        | 1093/5000 [01:26<04:15, 15.29it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▊                        | 1095/5000 [01:26<04:27, 14.62it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▊                        | 1097/5000 [01:26<04:09, 15.67it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▊                        | 1099/5000 [01:26<04:27, 14.60it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▊                        | 1102/5000 [01:26<04:02, 16.10it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▊                        | 1104/5000 [01:26<04:24, 14.75it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▊                        | 1106/5000 [01:26<04:07, 15.73it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▊                        | 1108/5000 [01:26<03:56, 16.47it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▉                        | 1110/5000 [01:27<05:33, 11.65it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▉                        | 1112/5000 [01:27<04:58, 13.03it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▉                        | 1114/5000 [01:27<04:34, 14.13it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▉                        | 1116/5000 [01:27<05:01, 12.87it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▉                        | 1119/5000 [01:27<04:11, 15.46it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▉                        | 1121/5000 [01:28<04:32, 14.25it/s]
# Augmenting 400x OSCC Histopathological Images:  22%|██████▉                        | 1123/5000 [01:28<04:14, 15.24it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|██████▉                        | 1126/5000 [01:28<03:41, 17.46it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|██████▉                        | 1128/5000 [01:28<04:03, 15.90it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████                        | 1131/5000 [01:28<04:20, 14.86it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████                        | 1134/5000 [01:28<03:53, 16.57it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████                        | 1136/5000 [01:28<04:11, 15.35it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████                        | 1138/5000 [01:29<04:08, 15.54it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████                        | 1140/5000 [01:29<04:42, 13.64it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████                        | 1142/5000 [01:29<04:29, 14.30it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████                        | 1144/5000 [01:29<04:44, 13.57it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████                        | 1146/5000 [01:29<04:20, 14.81it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████                        | 1148/5000 [01:29<04:43, 13.59it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████▏                       | 1151/5000 [01:29<04:04, 15.75it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████▏                       | 1153/5000 [01:30<03:50, 16.67it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████▏                       | 1155/5000 [01:30<04:14, 15.08it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████▏                       | 1157/5000 [01:30<03:58, 16.14it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████▏                       | 1159/5000 [01:30<04:41, 13.64it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████▏                       | 1162/5000 [01:30<04:26, 14.40it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████▏                       | 1165/5000 [01:30<04:01, 15.86it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████▏                       | 1167/5000 [01:31<04:28, 14.26it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████▏                       | 1169/5000 [01:31<04:08, 15.39it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████▎                       | 1171/5000 [01:31<03:55, 16.28it/s]
# Augmenting 400x OSCC Histopathological Images:  23%|███████▎                       | 1173/5000 [01:31<04:10, 15.26it/s]
# Augmenting 400x OSCC Histopathological Images:  24%|███████▎                       | 1176/5000 [01:31<03:58, 16.06it/s]
# Augmenting 400x OSCC Histopathological Images:  24%|███████▎                       | 1178/5000 [01:31<03:51, 16.48it/s]
# Augmenting 400x OSCC Histopathological Images:  24%|███████▎                       | 1180/5000 [01:31<04:14, 15.04it/s]
# Augmenting 400x OSCC Histopathological Images:  24%|███████▎                       | 1182/5000 [01:31<03:57, 16.08it/s]
# Augmenting 400x OSCC Histopathological Images:  24%|███████▎                       | 1184/5000 [01:32<03:49, 16.64it/s]
# Augmenting 400x OSCC Histopathological Images:  24%|███████▎                       | 1186/5000 [01:32<04:20, 14.66it/s]
# Augmenting 400x OSCC Histopathological Images:  24%|███████▎                       | 1188/5000 [01:32<04:03, 15.65it/s]
# Augmenting 400x OSCC Histopathological Images:  24%|███████▍                       | 1190/5000 [01:32<04:28, 14.19it/s]
# Augmenting 400x OSCC Histopathological Images:  24%|███████▍                       | 1192/5000 [01:32<04:06, 15.44it/s]
# Augmenting 400x OSCC Histopathological Images:  24%|███████▍                       | 1194/5000 [01:32<04:24, 14.41it/s]
# Augmenting 400x OSCC Histopathological Images:  24%|███████▍                       | 1196/5000 [01:32<04:02, 15.71it/s]
# Augmenting 400x OSCC Histopathological Images:  24%|███████▍                       | 1199/5000 [01:33<04:13, 14.99it/s]
# Augmenting 400x OSCC Histopathological Images:  24%|███████▍                       | 1202/5000 [01:33<03:43, 16.99it/s]
# Augmenting 400x OSCC Histopathological Images:  24%|███████▍                       | 1205/5000 [01:33<04:14, 14.93it/s]
# Augmenting 400x OSCC Histopathological Images:  24%|███████▍                       | 1208/5000 [01:33<03:48, 16.58it/s]
