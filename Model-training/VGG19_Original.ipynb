# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
IMAGE_H = 256
IMAGE_W = 256
BATCH_SIZE = 32
channels = 3
epochs= 50
SEED = 123

# %%
import os

# %%
base_dir = os.path.abspath(r'E:\ORAL_CANCER\oral_datasets\original_dataset')

# %%
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

# %%
print("Training directory:", train_dir)
print("Validation directory:", val_dir)
print("Test directory:", test_dir)
# Out:
# Training directory: E:\ORAL_CANCER\oral_datasets\original_dataset\train
# Validation directory: E:\ORAL_CANCER\oral_datasets\original_dataset\val
# Test directory: E:\ORAL_CANCER\oral_datasets\original_dataset\test

# %%
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    shuffle=True,
    image_size=(IMAGE_H, IMAGE_W),
    batch_size=BATCH_SIZE,
    seed=SEED
)

val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir,
    shuffle=True,
    image_size=(IMAGE_H, IMAGE_W),
    batch_size=BATCH_SIZE,
    seed=SEED
)

test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    shuffle=False,
    image_size=(IMAGE_H, IMAGE_W),
    batch_size=BATCH_SIZE
)

# ✅ Save class names BEFORE any transformation
class_names = test_dataset.class_names
print("Class Names:", class_names)
# Out:
# Found 486 files belonging to 2 classes.
# Found 104 files belonging to 2 classes.
# Found 106 files belonging to 2 classes.
# Class Names: ['400x Normal Oral Cavity Histopathological Images', '400x OSCC Histopathological Images']

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)

# %%
from tensorflow.keras.applications.vgg19 import VGG19

# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Dropout
from tensorflow.keras.models import Model

# %%
IMAGE_SIZE = [256,256]
vgg = VGG19(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %%
for layer in vgg.layers:
    layer.trainable = False

# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Dropout
x = Flatten()(vgg.output)

prediction = Dense(2, activation='softmax')(x)

# %%
from tensorflow.keras.models import Model
model = Model(inputs=vgg.input, outputs=prediction)

# view the structure of the model
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 2)                 65538
#
# =================================================================
# Total params: 20,089,922
# Trainable params: 65,538
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

# %%
model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

# %%
history=model.fit(
    train_dataset,
    epochs=epochs,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data=val_dataset,
)
# Out:
# Epoch 1/50
# c:\Users\gaura\anaconda3\envs\my_env\lib\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 16/16 [==============================] - 19833s 1s/step - loss: 4.2782 - accuracy: 0.6132 - val_loss: 4.1041 - val_accuracy: 0.6731
# Epoch 2/50
# 16/16 [==============================] - 7s 453ms/step - loss: 1.9473 - accuracy: 0.7881 - val_loss: 4.0191 - val_accuracy: 0.6635
# Epoch 3/50
# 16/16 [==============================] - 7s 453ms/step - loss: 0.7891 - accuracy: 0.8848 - val_loss: 4.1762 - val_accuracy: 0.6538
# Epoch 4/50
# 16/16 [==============================] - 7s 452ms/step - loss: 0.2872 - accuracy: 0.9342 - val_loss: 3.7331 - val_accuracy: 0.6827
# Epoch 5/50
# 16/16 [==============================] - 7s 454ms/step - loss: 0.1066 - accuracy: 0.9774 - val_loss: 3.8857 - val_accuracy: 0.6827
# Epoch 6/50
# 16/16 [==============================] - 7s 453ms/step - loss: 0.0823 - accuracy: 0.9856 - val_loss: 3.7190 - val_accuracy: 0.6827
# Epoch 7/50
# 16/16 [==============================] - 7s 453ms/step - loss: 0.0707 - accuracy: 0.9774 - val_loss: 3.5996 - val_accuracy: 0.7115
# Epoch 8/50
# 16/16 [==============================] - 7s 454ms/step - loss: 0.0430 - accuracy: 0.9877 - val_loss: 3.7688 - val_accuracy: 0.6731
# Epoch 9/50
# 16/16 [==============================] - 7s 454ms/step - loss: 0.0569 - accuracy: 0.9835 - val_loss: 3.6223 - val_accuracy: 0.6827
# Epoch 10/50
# 16/16 [==============================] - 7s 453ms/step - loss: 0.0326 - accuracy: 0.9835 - val_loss: 3.6187 - val_accuracy: 0.7019
# Epoch 11/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.0513 - accuracy: 0.9877 - val_loss: 3.7819 - val_accuracy: 0.6731
# Epoch 12/50
# 16/16 [==============================] - 7s 475ms/step - loss: 0.0576 - accuracy: 0.9877 - val_loss: 3.5768 - val_accuracy: 0.7115
# Epoch 13/50
# 16/16 [==============================] - 7s 455ms/step - loss: 0.0394 - accuracy: 0.9877 - val_loss: 3.6753 - val_accuracy: 0.7019
# Epoch 14/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.0585 - accuracy: 0.9835 - val_loss: 3.7448 - val_accuracy: 0.7019
# Epoch 15/50
# 16/16 [==============================] - 7s 457ms/step - loss: 0.0438 - accuracy: 0.9856 - val_loss: 3.5928 - val_accuracy: 0.7019
# Epoch 16/50
# 16/16 [==============================] - 7s 459ms/step - loss: 0.0753 - accuracy: 0.9835 - val_loss: 4.0921 - val_accuracy: 0.6538
# Epoch 17/50
# 16/16 [==============================] - 7s 457ms/step - loss: 0.0510 - accuracy: 0.9856 - val_loss: 3.6062 - val_accuracy: 0.7115
# Epoch 18/50
# 16/16 [==============================] - 7s 478ms/step - loss: 0.0495 - accuracy: 0.9856 - val_loss: 3.7837 - val_accuracy: 0.6923
# Epoch 19/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.0501 - accuracy: 0.9856 - val_loss: 3.6257 - val_accuracy: 0.7115
# Epoch 20/50
# 16/16 [==============================] - 7s 458ms/step - loss: 0.0545 - accuracy: 0.9897 - val_loss: 3.9075 - val_accuracy: 0.6635
# Epoch 21/50
# 16/16 [==============================] - 7s 458ms/step - loss: 0.1077 - accuracy: 0.9794 - val_loss: 3.5766 - val_accuracy: 0.7115
# Epoch 22/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.0707 - accuracy: 0.9877 - val_loss: 3.7700 - val_accuracy: 0.6827
# Epoch 23/50
# 16/16 [==============================] - 7s 458ms/step - loss: 0.0998 - accuracy: 0.9856 - val_loss: 3.7236 - val_accuracy: 0.7019
# Epoch 24/50
# 16/16 [==============================] - 7s 457ms/step - loss: 0.1053 - accuracy: 0.9712 - val_loss: 3.6022 - val_accuracy: 0.7019
# Epoch 25/50
# 16/16 [==============================] - 7s 478ms/step - loss: 0.0689 - accuracy: 0.9877 - val_loss: 3.7164 - val_accuracy: 0.7212
# Epoch 26/50
# 16/16 [==============================] - 7s 458ms/step - loss: 0.0652 - accuracy: 0.9856 - val_loss: 3.8616 - val_accuracy: 0.6731
# Epoch 27/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.0621 - accuracy: 0.9877 - val_loss: 3.6803 - val_accuracy: 0.7115
# Epoch 28/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.0868 - accuracy: 0.9856 - val_loss: 4.3044 - val_accuracy: 0.6442
# Epoch 29/50
# 16/16 [==============================] - 7s 455ms/step - loss: 0.0503 - accuracy: 0.9877 - val_loss: 3.7618 - val_accuracy: 0.7308
# Epoch 30/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.0682 - accuracy: 0.9877 - val_loss: 4.0457 - val_accuracy: 0.6731
# Epoch 31/50
# 16/16 [==============================] - 7s 455ms/step - loss: 0.0863 - accuracy: 0.9835 - val_loss: 3.6532 - val_accuracy: 0.7019
# Epoch 32/50
# 16/16 [==============================] - 7s 454ms/step - loss: 0.0552 - accuracy: 0.9835 - val_loss: 3.6673 - val_accuracy: 0.7115
# Epoch 33/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.0905 - accuracy: 0.9856 - val_loss: 3.7185 - val_accuracy: 0.7308
# Epoch 34/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.0807 - accuracy: 0.9897 - val_loss: 3.8005 - val_accuracy: 0.6923
# Epoch 35/50
# 16/16 [==============================] - 7s 455ms/step - loss: 0.0741 - accuracy: 0.9877 - val_loss: 3.6828 - val_accuracy: 0.7019
# Epoch 36/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.0419 - accuracy: 0.9897 - val_loss: 3.6804 - val_accuracy: 0.7115
# Epoch 37/50
# 16/16 [==============================] - 7s 454ms/step - loss: 0.0818 - accuracy: 0.9877 - val_loss: 3.6412 - val_accuracy: 0.7019
# Epoch 38/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.0663 - accuracy: 0.9877 - val_loss: 3.7213 - val_accuracy: 0.7115
# Epoch 39/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.0710 - accuracy: 0.9856 - val_loss: 3.7545 - val_accuracy: 0.6827
# Epoch 40/50
# 16/16 [==============================] - 7s 458ms/step - loss: 0.0550 - accuracy: 0.9877 - val_loss: 3.6995 - val_accuracy: 0.7115
# Epoch 41/50
# 16/16 [==============================] - 7s 460ms/step - loss: 0.0794 - accuracy: 0.9856 - val_loss: 3.6651 - val_accuracy: 0.7115
# Epoch 42/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.0616 - accuracy: 0.9897 - val_loss: 3.8521 - val_accuracy: 0.6827
# Epoch 43/50
# 16/16 [==============================] - 7s 457ms/step - loss: 0.1033 - accuracy: 0.9835 - val_loss: 3.8508 - val_accuracy: 0.7596
# Epoch 44/50
# 16/16 [==============================] - 7s 457ms/step - loss: 0.1320 - accuracy: 0.9815 - val_loss: 4.3586 - val_accuracy: 0.7500
# Epoch 45/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.1149 - accuracy: 0.9733 - val_loss: 3.8946 - val_accuracy: 0.7308
# Epoch 46/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.0702 - accuracy: 0.9877 - val_loss: 3.8437 - val_accuracy: 0.7115
# Epoch 47/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.0444 - accuracy: 0.9897 - val_loss: 3.8185 - val_accuracy: 0.7212
# Epoch 48/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.1038 - accuracy: 0.9877 - val_loss: 4.4511 - val_accuracy: 0.6538
# Epoch 49/50
# 16/16 [==============================] - 7s 454ms/step - loss: 0.1154 - accuracy: 0.9774 - val_loss: 4.0240 - val_accuracy: 0.7404
# Epoch 50/50
# 16/16 [==============================] - 7s 456ms/step - loss: 0.0590 - accuracy: 0.9877 - val_loss: 3.8520 - val_accuracy: 0.7212

# %%
model.evaluate(test_dataset)
# Out:
# 4/4 [==============================] - 7s 2s/step - loss: 2.7995 - accuracy: 0.7075
# [2.7995450496673584, 0.7075471878051758]

# %%
acc= history.history['accuracy']
val_acc = history.history['val_accuracy']

loss= history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(range(epochs), acc, label='Training Accuracy')
plt.plot(range(epochs), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1,2,2)
plt.plot(range(epochs), loss, label='Training Loss')
plt.plot(range(epochs), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Accuracy')
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
import numpy as np

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# Extract all test images and labels from the test dataset
test_images = []
test_labels = []

for images, labels in test_dataset:
    test_images.append(images)
    test_labels.append(labels)

test_images = tf.concat(test_images, axis=0)
test_labels = tf.concat(test_labels, axis=0)

# Predict using the trained model
y_pred = np.argmax(model.predict(test_images), axis=-1)
y_true = test_labels.numpy()

# Get class names from the dataset
class_names = test_dataset.class_names
print("Class Names:", class_names)

# Print classification report and confusion matrix
print("Classification Report:\n", classification_report(y_true, y_pred, labels=range(len(class_names)), target_names=class_names))
print("Confusion Matrix:\n", confusion_matrix(y_true, y_pred))
# Out:
# 4/4 [==============================] - 2s 444ms/step
# Class Names: ['400x Normal Oral Cavity Histopathological Images', '400x OSCC Histopathological Images']
# Classification Report:
#                                                    precision    recall  f1-score   support
#
# 400x Normal Oral Cavity Histopathological Images       0.50      0.48      0.49        31
#               400x OSCC Histopathological Images       0.79      0.80      0.79        75
#
#                                         accuracy                           0.71       106
#                                        macro avg       0.64      0.64      0.64       106
#                                     weighted avg       0.70      0.71      0.71       106
#
# Confusion Matrix:
#  [[15 16]
#  [15 60]]

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score

# Convert true labels and predicted labels to numpy arrays if they aren't already
y_true = test_labels.numpy() if hasattr(test_labels, 'numpy') else test_labels
y_pred = np.asarray(y_pred)

# Generate confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Compute overall metrics
precision = precision_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

# Compute specificity for each class
TN = np.zeros(len(class_names))
FP = np.zeros(len(class_names))
for i in range(len(class_names)):
    TP = cm[i, i]
    FN = np.sum(cm[i, :]) - TP
    FP[i] = np.sum(cm[:, i]) - TP
    TN[i] = np.sum(cm) - (TP + FP[i] + FN)

specificity = np.mean(TN / (TN + FP))

# Display results
print(f"\nOverall Precision (macro):   {precision:.4f}")
print(f"Overall Recall (macro):      {recall:.4f}")
print(f"Overall Specificity (macro): {specificity:.4f}")
print(f"Overall F1 Score (macro):    {f1:.4f}")
# Out:
# Overall Precision (macro):   0.6447
# Overall Recall (macro):      0.6419
# Overall Specificity (macro): 0.6419
# Overall F1 Score (macro):    0.6433

# %%
# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score

# Collect true labels and predicted scores
y_true = []
y_scores = []

for images, labels in test_dataset:
    preds = model.predict(images)

    # If your model has a sigmoid output for binary classification:
    if preds.shape[1] == 1 or len(preds.shape) == 1:
        preds = preds.flatten()
    else:
        preds = preds[:, 1]  # Use the probability of class 1 in softmax

    y_true.extend(labels.numpy())
    y_scores.extend(preds)

y_true = np.array(y_true)
y_scores = np.array(y_scores)

# ROC Curve and AUC
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
auc_score = roc_auc_score(y_true, y_scores)
print(f"AUC Score: {auc_score:.4f}")

# Plot ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {auc_score:.4f})", color='blue')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate (Recall)")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 38ms/step
# AUC Score: 0.7282
