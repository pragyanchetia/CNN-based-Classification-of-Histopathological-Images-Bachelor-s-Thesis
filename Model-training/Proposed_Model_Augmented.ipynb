# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
IMAGE_H = 256
IMAGE_W = 256
BATCH_SIZE = 32
channels = 3
epochs= 50
SEED = 123

# %%
import os

# %%
base_dir = os.path.abspath(r'E:\ORAL_CANCER\oral_datasets\augmented_balanced_set')

# %%
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

# %%
print("Training directory:", train_dir)
print("Validation directory:", val_dir)
print("Test directory:", test_dir)
# Out:
# Training directory: E:\ORAL_CANCER\oral_datasets\augmented_balanced_set\train
# Validation directory: E:\ORAL_CANCER\oral_datasets\augmented_balanced_set\val
# Test directory: E:\ORAL_CANCER\oral_datasets\augmented_balanced_set\test

# %%
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    shuffle=True,
    image_size=(IMAGE_H, IMAGE_W),
    batch_size=BATCH_SIZE,
    seed=SEED
)

val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir,
    shuffle=True,
    image_size=(IMAGE_H, IMAGE_W),
    batch_size=BATCH_SIZE,
    seed=SEED
)

test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    shuffle=False,  # Typically you don't shuffle test data
    image_size=(IMAGE_H, IMAGE_W),
    batch_size=BATCH_SIZE
)
# Out:
# Found 10000 files belonging to 2 classes.
# Found 104 files belonging to 2 classes.
# Found 106 files belonging to 2 classes.

# %%
BATCH_SIZE = 32
IMAGE_H, IMAGE_W = 256, 256
CHANNELS = 3
N_CLASSES = 2

model = models.Sequential([
    layers.Conv2D(32, kernel_size = (3,3), activation='relu', input_shape=(IMAGE_H, IMAGE_W, CHANNELS)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.40),
    layers.Conv2D(64,  kernel_size = (3,3), activation='relu'),
    layers.Conv2D(64,  kernel_size = (3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.40),
    layers.Conv2D(128,  kernel_size = (3,3), activation='relu'),
    layers.Conv2D(128,  kernel_size = (3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(N_CLASSES, activation='softmax'),
])

# %%
# view the structure of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  dropout (Dropout)           (None, 127, 127, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      18496
#
#  conv2d_2 (Conv2D)           (None, 123, 123, 64)      36928
#
#  max_pooling2d_1 (MaxPooling  (None, 61, 61, 64)       0
#  2D)
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 128)       73856
#
#  conv2d_4 (Conv2D)           (None, 26, 26, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 21632)             0
#
#  dense (Dense)               (None, 64)                1384512
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 1,664,418
# Trainable params: 1,664,418
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

# %%
model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

# %%
history=model.fit(
    train_dataset,
    epochs=epochs,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data=val_dataset,
)
# Out:
# Epoch 1/50
# c:\Users\gaura\anaconda3\envs\my_env\lib\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 313/313 [==============================] - 55s 150ms/step - loss: 1.1929 - accuracy: 0.5256 - val_loss: 0.7448 - val_accuracy: 0.3750
# Epoch 2/50
# 313/313 [==============================] - 45s 142ms/step - loss: 0.7095 - accuracy: 0.5617 - val_loss: 0.7144 - val_accuracy: 0.4327
# Epoch 3/50
# 313/313 [==============================] - 45s 142ms/step - loss: 0.6692 - accuracy: 0.5946 - val_loss: 0.7158 - val_accuracy: 0.4519
# Epoch 4/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.6491 - accuracy: 0.6146 - val_loss: 0.6977 - val_accuracy: 0.4808
# Epoch 5/50
# 313/313 [==============================] - 45s 142ms/step - loss: 0.6229 - accuracy: 0.6460 - val_loss: 0.6152 - val_accuracy: 0.6731
# Epoch 6/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.5893 - accuracy: 0.6832 - val_loss: 0.6077 - val_accuracy: 0.6635
# Epoch 7/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.5485 - accuracy: 0.7155 - val_loss: 0.5792 - val_accuracy: 0.6923
# Epoch 8/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.5127 - accuracy: 0.7467 - val_loss: 0.5682 - val_accuracy: 0.6923
# Epoch 9/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.4733 - accuracy: 0.7744 - val_loss: 0.5226 - val_accuracy: 0.7788
# Epoch 10/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.4199 - accuracy: 0.8080 - val_loss: 0.5465 - val_accuracy: 0.7212
# Epoch 11/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.3694 - accuracy: 0.8297 - val_loss: 0.5923 - val_accuracy: 0.7019
# Epoch 12/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.3290 - accuracy: 0.8534 - val_loss: 0.5933 - val_accuracy: 0.7308
# Epoch 13/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.2887 - accuracy: 0.8745 - val_loss: 0.5534 - val_accuracy: 0.7596
# Epoch 14/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.2514 - accuracy: 0.8921 - val_loss: 0.6143 - val_accuracy: 0.7115
# Epoch 15/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.2186 - accuracy: 0.9074 - val_loss: 0.5722 - val_accuracy: 0.7596
# Epoch 16/50
# 313/313 [==============================] - 45s 144ms/step - loss: 0.1913 - accuracy: 0.9180 - val_loss: 0.6915 - val_accuracy: 0.7692
# Epoch 17/50
# 313/313 [==============================] - 45s 144ms/step - loss: 0.1620 - accuracy: 0.9313 - val_loss: 0.7882 - val_accuracy: 0.7500
# Epoch 18/50
# 313/313 [==============================] - 45s 144ms/step - loss: 0.1431 - accuracy: 0.9426 - val_loss: 0.6948 - val_accuracy: 0.7404
# Epoch 19/50
# 313/313 [==============================] - 45s 144ms/step - loss: 0.1296 - accuracy: 0.9485 - val_loss: 0.6942 - val_accuracy: 0.7692
# Epoch 20/50
# 313/313 [==============================] - 45s 144ms/step - loss: 0.1165 - accuracy: 0.9544 - val_loss: 0.9572 - val_accuracy: 0.7019
# Epoch 21/50
# 313/313 [==============================] - 45s 144ms/step - loss: 0.1036 - accuracy: 0.9588 - val_loss: 0.7946 - val_accuracy: 0.7596
# Epoch 22/50
# 313/313 [==============================] - 45s 144ms/step - loss: 0.0839 - accuracy: 0.9659 - val_loss: 0.9408 - val_accuracy: 0.7500
# Epoch 23/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.0760 - accuracy: 0.9714 - val_loss: 0.9068 - val_accuracy: 0.7692
# Epoch 24/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.0821 - accuracy: 0.9690 - val_loss: 0.8231 - val_accuracy: 0.7885
# Epoch 25/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.0775 - accuracy: 0.9707 - val_loss: 0.9631 - val_accuracy: 0.7596
# Epoch 26/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.0794 - accuracy: 0.9705 - val_loss: 1.0753 - val_accuracy: 0.7788
# Epoch 27/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.0437 - accuracy: 0.9847 - val_loss: 1.0745 - val_accuracy: 0.8077
# Epoch 28/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.0387 - accuracy: 0.9872 - val_loss: 1.2454 - val_accuracy: 0.7500
# Epoch 29/50
# 313/313 [==============================] - 45s 144ms/step - loss: 0.0375 - accuracy: 0.9881 - val_loss: 1.0998 - val_accuracy: 0.8077
# Epoch 30/50
# 313/313 [==============================] - 45s 144ms/step - loss: 0.0503 - accuracy: 0.9827 - val_loss: 1.0361 - val_accuracy: 0.7788
# Epoch 31/50
# 313/313 [==============================] - 45s 144ms/step - loss: 0.0419 - accuracy: 0.9859 - val_loss: 1.1452 - val_accuracy: 0.7500
# Epoch 32/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.0352 - accuracy: 0.9882 - val_loss: 1.2709 - val_accuracy: 0.7788
# Epoch 33/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.0366 - accuracy: 0.9873 - val_loss: 1.2497 - val_accuracy: 0.7885
# Epoch 34/50
# 313/313 [==============================] - 45s 143ms/step - loss: 0.0330 - accuracy: 0.9896 - val_loss: 1.1101 - val_accuracy: 0.8269
# Epoch 35/50
# 313/313 [==============================] - 45s 144ms/step - loss: 0.0365 - accuracy: 0.9872 - val_loss: 1.3391 - val_accuracy: 0.7788
# Epoch 36/50
# 313/313 [==============================] - 45s 144ms/step - loss: 0.0469 - accuracy: 0.9852 - val_loss: 1.3730 - val_accuracy: 0.7788
# Epoch 37/50
# 313/313 [==============================] - 45s 144ms/step - loss: 0.0309 - accuracy: 0.9902 - val_loss: 1.3623 - val_accuracy: 0.7885
# Epoch 38/50
# 313/313 [==============================] - 45s 145ms/step - loss: 0.0287 - accuracy: 0.9905 - val_loss: 1.3520 - val_accuracy: 0.8077
# Epoch 39/50
# 313/313 [==============================] - 45s 144ms/step - loss: 0.0145 - accuracy: 0.9951 - val_loss: 1.5984 - val_accuracy: 0.7500
# Epoch 40/50
# 313/313 [==============================] - 45s 144ms/step - loss: 0.0132 - accuracy: 0.9961 - val_loss: 1.5563 - val_accuracy: 0.7885
# Epoch 41/50
# 313/313 [==============================] - 46s 146ms/step - loss: 0.0243 - accuracy: 0.9924 - val_loss: 1.4107 - val_accuracy: 0.7981
# Epoch 42/50
# 313/313 [==============================] - 46s 146ms/step - loss: 0.0409 - accuracy: 0.9863 - val_loss: 1.5416 - val_accuracy: 0.7981
# Epoch 43/50
# 313/313 [==============================] - 46s 146ms/step - loss: 0.0211 - accuracy: 0.9926 - val_loss: 1.3759 - val_accuracy: 0.8077
# Epoch 44/50
# 313/313 [==============================] - 46s 145ms/step - loss: 0.0364 - accuracy: 0.9878 - val_loss: 1.4129 - val_accuracy: 0.7981
# Epoch 45/50
# 313/313 [==============================] - 46s 146ms/step - loss: 0.0104 - accuracy: 0.9974 - val_loss: 1.6206 - val_accuracy: 0.7885
# Epoch 46/50
# 313/313 [==============================] - 46s 146ms/step - loss: 0.0285 - accuracy: 0.9913 - val_loss: 1.3355 - val_accuracy: 0.7788
# Epoch 47/50
# 313/313 [==============================] - 45s 145ms/step - loss: 0.0157 - accuracy: 0.9952 - val_loss: 1.5035 - val_accuracy: 0.7788
# Epoch 48/50
# 313/313 [==============================] - 46s 146ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 1.6632 - val_accuracy: 0.7981
# Epoch 49/50
# 313/313 [==============================] - 46s 146ms/step - loss: 0.0335 - accuracy: 0.9886 - val_loss: 1.6728 - val_accuracy: 0.7596
# Epoch 50/50
# 313/313 [==============================] - 46s 145ms/step - loss: 0.0243 - accuracy: 0.9916 - val_loss: 1.3579 - val_accuracy: 0.7885

# %%
model.evaluate(test_dataset)
# Out:
# 4/4 [==============================] - 1s 271ms/step - loss: 0.9548 - accuracy: 0.8585
# [0.954832911491394, 0.8584905862808228]

# %%
acc= history.history['accuracy']
val_acc = history.history['val_accuracy']

loss= history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(range(epochs), acc, label='Training Accuracy')
plt.plot(range(epochs), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1,2,2)
plt.plot(range(epochs), loss, label='Training Loss')
plt.plot(range(epochs), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Accuracy')
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
import numpy as np

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# Extract all test images and labels from the test dataset
test_images = []
test_labels = []

for images, labels in test_dataset:
    test_images.append(images)
    test_labels.append(labels)

test_images = tf.concat(test_images, axis=0)
test_labels = tf.concat(test_labels, axis=0)

# Predict using the trained model
y_pred = np.argmax(model.predict(test_images), axis=-1)
y_true = test_labels.numpy()

# Get class names from the dataset
class_names = test_dataset.class_names
print("Class Names:", class_names)

# Print classification report and confusion matrix
print("Classification Report:\n", classification_report(y_true, y_pred, labels=range(len(class_names)), target_names=class_names))
print("Confusion Matrix:\n", confusion_matrix(y_true, y_pred))
# Out:
# 4/4 [==============================] - 1s 82ms/step
# Class Names: ['400x Normal Oral Cavity Histopathological Images', '400x OSCC Histopathological Images']
# Classification Report:
#                                                    precision    recall  f1-score   support
#
# 400x Normal Oral Cavity Histopathological Images       0.79      0.71      0.75        31
#               400x OSCC Histopathological Images       0.88      0.92      0.90        75
#
#                                         accuracy                           0.86       106
#                                        macro avg       0.84      0.81      0.82       106
#                                     weighted avg       0.86      0.86      0.86       106
#
# Confusion Matrix:
#  [[22  9]
#  [ 6 69]]

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score

# Convert true labels and predicted labels to numpy arrays if they aren't already
y_true = test_labels.numpy() if hasattr(test_labels, 'numpy') else test_labels
y_pred = np.asarray(y_pred)

# Generate confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Compute overall metrics
precision = precision_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

# Compute specificity for each class
TN = np.zeros(len(class_names))
FP = np.zeros(len(class_names))
for i in range(len(class_names)):
    TP = cm[i, i]
    FN = np.sum(cm[i, :]) - TP
    FP[i] = np.sum(cm[:, i]) - TP
    TN[i] = np.sum(cm) - (TP + FP[i] + FN)

specificity = np.mean(TN / (TN + FP))

# Display results
print(f"\nOverall Precision (macro):   {precision:.4f}")
print(f"Overall Recall (macro):      {recall:.4f}")
print(f"Overall Specificity (macro): {specificity:.4f}")
print(f"Overall F1 Score (macro):    {f1:.4f}")
# Out:
# Overall Precision (macro):   0.8352
# Overall Recall (macro):      0.8148
# Overall Specificity (macro): 0.8148
# Overall F1 Score (macro):    0.8239

# %%
# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score

# Collect true labels and predicted scores
y_true = []
y_scores = []

for images, labels in test_dataset:
    preds = model.predict(images)

    # If your model has a sigmoid output for binary classification:
    if preds.shape[1] == 1 or len(preds.shape) == 1:
        preds = preds.flatten()
    else:
        preds = preds[:, 1]  # Use the probability of class 1 in softmax

    y_true.extend(labels.numpy())
    y_scores.extend(preds)

y_true = np.array(y_true)
y_scores = np.array(y_scores)

# ROC Curve and AUC
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
auc_score = roc_auc_score(y_true, y_scores)
print(f"AUC Score: {auc_score:.4f}")

# Plot ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {auc_score:.4f})", color='blue')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate (Recall)")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 31ms/step
# AUC Score: 0.8908
