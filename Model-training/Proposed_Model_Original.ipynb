# %%
import os
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
IMAGE_H = 256
IMAGE_W = 256
BATCH_SIZE = 32
channels = 3
epochs= 50
SEED = 123

# %%
import os

# %%
base_dir = os.path.abspath(r'E:\ORAL_CANCER\oral_datasets\original_dataset')

# %%
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

# %%
print("Training directory:", train_dir)
print("Validation directory:", val_dir)
print("Test directory:", test_dir)
# Out:
# Training directory: E:\ORAL_CANCER\oral_datasets\original_dataset\train
# Validation directory: E:\ORAL_CANCER\oral_datasets\original_dataset\val
# Test directory: E:\ORAL_CANCER\oral_datasets\original_dataset\test

# %%
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    shuffle=True,
    image_size=(IMAGE_H, IMAGE_W),
    batch_size=BATCH_SIZE,
    seed=SEED
)

val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir,
    shuffle=True,
    image_size=(IMAGE_H, IMAGE_W),
    batch_size=BATCH_SIZE,
    seed=SEED
)

test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    shuffle=False,
    image_size=(IMAGE_H, IMAGE_W),
    batch_size=BATCH_SIZE
)

# ✅ Save class names BEFORE any transformation
class_names = test_dataset.class_names
print("Class Names:", class_names)
# Out:
# Found 486 files belonging to 2 classes.
# Found 104 files belonging to 2 classes.
# Found 106 files belonging to 2 classes.
# Class Names: ['400x Normal Oral Cavity Histopathological Images', '400x OSCC Histopathological Images']

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)

# %%
BATCH_SIZE = 32
IMAGE_H, IMAGE_W = 256, 256
CHANNELS = 3
N_CLASSES = 2

model = models.Sequential([
    layers.Conv2D(32, kernel_size = (3,3), activation='relu', input_shape=(IMAGE_H, IMAGE_W, CHANNELS)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.40),
    layers.Conv2D(64,  kernel_size = (3,3), activation='relu'),
    layers.Conv2D(64,  kernel_size = (3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.40),
    layers.Conv2D(128,  kernel_size = (3,3), activation='relu'),
    layers.Conv2D(128,  kernel_size = (3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(N_CLASSES, activation='softmax'),
])

# %%
# view the structure of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  dropout (Dropout)           (None, 127, 127, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      18496
#
#  conv2d_2 (Conv2D)           (None, 123, 123, 64)      36928
#
#  max_pooling2d_1 (MaxPooling  (None, 61, 61, 64)       0
#  2D)
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 128)       73856
#
#  conv2d_4 (Conv2D)           (None, 26, 26, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 21632)             0
#
#  dense (Dense)               (None, 64)                1384512
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 1,664,418
# Trainable params: 1,664,418
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

# %%
model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

# %%
history=model.fit(
    train_dataset,
    epochs=epochs,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data=val_dataset,
)
# Out:
# Epoch 1/50
# c:\Users\gaura\anaconda3\envs\my_env\lib\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 16/16 [==============================] - 15s 247ms/step - loss: 3.9015 - accuracy: 0.6399 - val_loss: 0.6963 - val_accuracy: 0.7115
# Epoch 2/50
# 16/16 [==============================] - 2s 131ms/step - loss: 1.5107 - accuracy: 0.6235 - val_loss: 0.6631 - val_accuracy: 0.6058
# Epoch 3/50
# 16/16 [==============================] - 2s 130ms/step - loss: 1.1570 - accuracy: 0.5844 - val_loss: 0.6344 - val_accuracy: 0.7212
# Epoch 4/50
# 16/16 [==============================] - 2s 137ms/step - loss: 0.9796 - accuracy: 0.6317 - val_loss: 0.6346 - val_accuracy: 0.7115
# Epoch 5/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.9329 - accuracy: 0.6173 - val_loss: 0.6127 - val_accuracy: 0.7115
# Epoch 6/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.8212 - accuracy: 0.6399 - val_loss: 0.6071 - val_accuracy: 0.6923
# Epoch 7/50
# 16/16 [==============================] - 2s 130ms/step - loss: 0.8537 - accuracy: 0.6276 - val_loss: 0.6070 - val_accuracy: 0.7115
# Epoch 8/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.6206 - accuracy: 0.6872 - val_loss: 0.6427 - val_accuracy: 0.7019
# Epoch 9/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5938 - accuracy: 0.6996 - val_loss: 0.6412 - val_accuracy: 0.6923
# Epoch 10/50
# 16/16 [==============================] - 2s 130ms/step - loss: 0.6476 - accuracy: 0.6687 - val_loss: 0.6335 - val_accuracy: 0.6923
# Epoch 11/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5915 - accuracy: 0.6728 - val_loss: 0.6142 - val_accuracy: 0.6731
# Epoch 12/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.6182 - accuracy: 0.6955 - val_loss: 0.6281 - val_accuracy: 0.6827
# Epoch 13/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5827 - accuracy: 0.7222 - val_loss: 0.6319 - val_accuracy: 0.6731
# Epoch 14/50
# 16/16 [==============================] - 2s 132ms/step - loss: 0.5842 - accuracy: 0.7305 - val_loss: 0.6212 - val_accuracy: 0.6731
# Epoch 15/50
# 16/16 [==============================] - 2s 130ms/step - loss: 0.6004 - accuracy: 0.7058 - val_loss: 0.6035 - val_accuracy: 0.6827
# Epoch 16/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5813 - accuracy: 0.7202 - val_loss: 0.6044 - val_accuracy: 0.6827
# Epoch 17/50
# 16/16 [==============================] - 2s 138ms/step - loss: 0.5758 - accuracy: 0.7263 - val_loss: 0.6208 - val_accuracy: 0.6731
# Epoch 18/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5758 - accuracy: 0.7202 - val_loss: 0.6249 - val_accuracy: 0.7019
# Epoch 19/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5800 - accuracy: 0.7305 - val_loss: 0.6458 - val_accuracy: 0.6923
# Epoch 20/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5995 - accuracy: 0.7243 - val_loss: 0.6261 - val_accuracy: 0.7019
# Epoch 21/50
# 16/16 [==============================] - 2s 132ms/step - loss: 0.5623 - accuracy: 0.7407 - val_loss: 0.6253 - val_accuracy: 0.7019
# Epoch 22/50
# 16/16 [==============================] - 2s 132ms/step - loss: 0.5762 - accuracy: 0.7181 - val_loss: 0.6240 - val_accuracy: 0.7019
# Epoch 23/50
# 16/16 [==============================] - 2s 130ms/step - loss: 0.5432 - accuracy: 0.7243 - val_loss: 0.6476 - val_accuracy: 0.6346
# Epoch 24/50
# 16/16 [==============================] - 2s 130ms/step - loss: 0.5341 - accuracy: 0.7387 - val_loss: 0.6574 - val_accuracy: 0.6250
# Epoch 25/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5606 - accuracy: 0.7263 - val_loss: 0.6229 - val_accuracy: 0.7212
# Epoch 26/50
# 16/16 [==============================] - 2s 138ms/step - loss: 0.5341 - accuracy: 0.7428 - val_loss: 0.6143 - val_accuracy: 0.7404
# Epoch 27/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5620 - accuracy: 0.7243 - val_loss: 0.6405 - val_accuracy: 0.6442
# Epoch 28/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5344 - accuracy: 0.7531 - val_loss: 0.6380 - val_accuracy: 0.6538
# Epoch 29/50
# 16/16 [==============================] - 2s 132ms/step - loss: 0.5890 - accuracy: 0.7160 - val_loss: 0.5964 - val_accuracy: 0.7308
# Epoch 30/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5572 - accuracy: 0.7366 - val_loss: 0.6713 - val_accuracy: 0.6154
# Epoch 31/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5736 - accuracy: 0.7325 - val_loss: 0.6696 - val_accuracy: 0.6250
# Epoch 32/50
# 16/16 [==============================] - 2s 130ms/step - loss: 0.5498 - accuracy: 0.7263 - val_loss: 0.6491 - val_accuracy: 0.6250
# Epoch 33/50
# 16/16 [==============================] - 2s 130ms/step - loss: 0.5244 - accuracy: 0.7428 - val_loss: 0.6142 - val_accuracy: 0.7115
# Epoch 34/50
# 16/16 [==============================] - 2s 130ms/step - loss: 0.5330 - accuracy: 0.7407 - val_loss: 0.6199 - val_accuracy: 0.6731
# Epoch 35/50
# 16/16 [==============================] - 2s 130ms/step - loss: 0.5179 - accuracy: 0.7510 - val_loss: 0.6332 - val_accuracy: 0.6538
# Epoch 36/50
# 16/16 [==============================] - 2s 134ms/step - loss: 0.5125 - accuracy: 0.7695 - val_loss: 0.6206 - val_accuracy: 0.6923
# Epoch 37/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.4965 - accuracy: 0.7490 - val_loss: 0.6166 - val_accuracy: 0.6731
# Epoch 38/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5325 - accuracy: 0.7469 - val_loss: 0.6071 - val_accuracy: 0.7115
# Epoch 39/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5110 - accuracy: 0.7634 - val_loss: 0.6379 - val_accuracy: 0.6538
# Epoch 40/50
# 16/16 [==============================] - 2s 130ms/step - loss: 0.5140 - accuracy: 0.7490 - val_loss: 0.6263 - val_accuracy: 0.6635
# Epoch 41/50
# 16/16 [==============================] - 2s 130ms/step - loss: 0.4946 - accuracy: 0.7613 - val_loss: 0.6475 - val_accuracy: 0.6346
# Epoch 42/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.4920 - accuracy: 0.7922 - val_loss: 0.6420 - val_accuracy: 0.6250
# Epoch 43/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.4947 - accuracy: 0.7819 - val_loss: 0.6388 - val_accuracy: 0.6346
# Epoch 44/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.4788 - accuracy: 0.7613 - val_loss: 0.7089 - val_accuracy: 0.5096
# Epoch 45/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.4915 - accuracy: 0.7634 - val_loss: 0.6603 - val_accuracy: 0.6538
# Epoch 46/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.4762 - accuracy: 0.7695 - val_loss: 0.6439 - val_accuracy: 0.6635
# Epoch 47/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.4778 - accuracy: 0.7654 - val_loss: 0.6518 - val_accuracy: 0.6538
# Epoch 48/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5062 - accuracy: 0.7531 - val_loss: 0.7236 - val_accuracy: 0.4712
# Epoch 49/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.4997 - accuracy: 0.7551 - val_loss: 0.6705 - val_accuracy: 0.6154
# Epoch 50/50
# 16/16 [==============================] - 2s 131ms/step - loss: 0.4851 - accuracy: 0.7695 - val_loss: 0.6037 - val_accuracy: 0.6923

# %%
model.evaluate(test_dataset)
# Out:
# 4/4 [==============================] - 1s 271ms/step - loss: 0.5741 - accuracy: 0.7642
# [0.5740583539009094, 0.7641509175300598]

# %%
acc= history.history['accuracy']
val_acc = history.history['val_accuracy']

loss= history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(range(epochs), acc, label='Training Accuracy')
plt.plot(range(epochs), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1,2,2)
plt.plot(range(epochs), loss, label='Training Loss')
plt.plot(range(epochs), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Accuracy')
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
import numpy as np

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# Extract all test images and labels from the test dataset
test_images = []
test_labels = []

for images, labels in test_dataset:
    test_images.append(images)
    test_labels.append(labels)

test_images = tf.concat(test_images, axis=0)
test_labels = tf.concat(test_labels, axis=0)

# Predict using the trained model
y_pred = np.argmax(model.predict(test_images), axis=-1)
y_true = test_labels.numpy()

# Get class names from the dataset
class_names = test_dataset.class_names
print("Class Names:", class_names)

# Print classification report and confusion matrix
print("Classification Report:\n", classification_report(y_true, y_pred, labels=range(len(class_names)), target_names=class_names))
print("Confusion Matrix:\n", confusion_matrix(y_true, y_pred))
# Out:
# 4/4 [==============================] - 1s 128ms/step
# Class Names: ['400x Normal Oral Cavity Histopathological Images', '400x OSCC Histopathological Images']
# Classification Report:
#                                                    precision    recall  f1-score   support
#
# 400x Normal Oral Cavity Histopathological Images       0.65      0.42      0.51        31
#               400x OSCC Histopathological Images       0.79      0.91      0.84        75
#
#                                         accuracy                           0.76       106
#                                        macro avg       0.72      0.66      0.68       106
#                                     weighted avg       0.75      0.76      0.75       106
#
# Confusion Matrix:
#  [[13 18]
#  [ 7 68]]

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score

# Convert true labels and predicted labels to numpy arrays if they aren't already
y_true = test_labels.numpy() if hasattr(test_labels, 'numpy') else test_labels
y_pred = np.asarray(y_pred)

# Generate confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Compute overall metrics
precision = precision_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

# Compute specificity for each class
TN = np.zeros(len(class_names))
FP = np.zeros(len(class_names))
for i in range(len(class_names)):
    TP = cm[i, i]
    FN = np.sum(cm[i, :]) - TP
    FP[i] = np.sum(cm[:, i]) - TP
    TN[i] = np.sum(cm) - (TP + FP[i] + FN)

specificity = np.mean(TN / (TN + FP))

# Display results
print(f"\nOverall Precision (macro):   {precision:.4f}")
print(f"Overall Recall (macro):      {recall:.4f}")
print(f"Overall Specificity (macro): {specificity:.4f}")
print(f"Overall F1 Score (macro):    {f1:.4f}")
# Out:
# Overall Precision (macro):   0.7203
# Overall Recall (macro):      0.6630
# Overall Specificity (macro): 0.6630
# Overall F1 Score (macro):    0.6773

# %%
# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score

# Collect true labels and predicted scores
y_true = []
y_scores = []

for images, labels in test_dataset:
    preds = model.predict(images)

    # If your model has a sigmoid output for binary classification:
    if preds.shape[1] == 1 or len(preds.shape) == 1:
        preds = preds.flatten()
    else:
        preds = preds[:, 1]  # Use the probability of class 1 in softmax

    y_true.extend(labels.numpy())
    y_scores.extend(preds)

y_true = np.array(y_true)
y_scores = np.array(y_scores)

# ROC Curve and AUC
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
auc_score = roc_auc_score(y_true, y_scores)
print(f"AUC Score: {auc_score:.4f}")

# Plot ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {auc_score:.4f})", color='blue')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate (Recall)")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 35ms/step
# AUC Score: 0.7763
